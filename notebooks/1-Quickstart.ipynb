# %% [markdown]
# # GraphRAG Quickstart

# %% [markdown]
# ## Prerequisites
# Install 3rd party packages, not part of the Python Standard Library, to run the notebook

# %%
! pip install devtools python-magic requests tqdm
# Out:
# Requirement already satisfied: devtools in /graphrag-accelerator/.venv/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: python-magic in /graphrag-accelerator/.venv/lib/python3.10/site-packages (0.4.27)
# Requirement already satisfied: requests in /graphrag-accelerator/.venv/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: tqdm in /graphrag-accelerator/.venv/lib/python3.10/site-packages (4.66.4)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from devtools) (2.4.1)
# Requirement already satisfied: executing>=1.1.1 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from devtools) (2.0.1)
# Requirement already satisfied: pygments>=2.15.0 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from devtools) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from requests) (2024.7.4)
# Requirement already satisfied: six>=1.12.0 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from asttokens<3.0.0,>=2.0.0->devtools) (1.16.0)

# %%
import getpass
import json
import time
from pathlib import Path

import magic
from devtools import pprint
from tqdm import tqdm

# %%
import requests

# %% [markdown]
# ## (REQUIRED) User Configuration
# Set the API subscription key, API base endpoint, and some file directory names that will be referenced later in the notebook.

# %% [markdown]
# #### API subscription key
#
# APIM supports multiple forms of authentication and access control (e.g. managed identity). For this notebook demonstration, we will use a **[subscription key](https://learn.microsoft.com/en-us/azure/api-management/api-management-subscriptions)**. To locate this key, visit the Azure Portal. The subscription key can be found under `<my_resource_group> --> <API Management service> --> <APIs> --> <Subscriptions> --> <Built-in all-access subscription> Primary Key`. For multiple API users, individual subscription keys can be generated.

# %%
# ocp_apim_subscription_key = getpass.getpass(
#     "Enter the subscription key to the GraphRag APIM:"
# )
ocp_apim_subscription_key = "a40d6ba55d0d4b50a517234e3fc5430b"
"""
"Ocp-Apim-Subscription-Key": 
    This is a custom HTTP header used by Azure API Management service (APIM) to 
    authenticate API requests. The value for this key should be set to the subscription 
    key provided by the Azure APIM instance in your GraphRAG resource group.
"""
headers = {"Ocp-Apim-Subscription-Key": ocp_apim_subscription_key}

# %% [markdown]
# #### Setup directories and API endpoint
#
# For demonstration purposes, please use the provided `get-wiki-articles.py` script to download a small set of wikipedia articles or provide your own data (graphrag requires txt files to be utf-8 encoded).

# %%
"""
These parameters must be defined by the notebook user:

- file_directory: a local directory of text files. The file structure should be flat,
                  with no nested directories. (i.e. file_directory/file1.txt, file_directory/file2.txt, etc.)
- storage_name:   a unique name to identify a blob storage container in Azure where files
                  from `file_directory` will be uploaded.
- index_name:     a unique name to identify a single graphrag knowledge graph index.
                  Note: Multiple indexes may be created from the same `storage_name` blob storage container.
- endpoint:       the base/endpoint URL for the GraphRAG API (this is the Gateway URL found in the APIM resource).
"""

file_directory = "Marpol"
storage_name = "https://stographrag.blob.core.windows.net/bwgma-kb"
index_name = "marpol2-i"
endpoint = "https://apim-6bmgl4mbrqugu.azure-api.net"

# %%
assert (
    file_directory != "" and storage_name != "" and index_name != "" and endpoint != ""
)

# %% [markdown]
# ## Upload Files
#
# For a demonstration of how to index data in graphrag, we first need to ingest a few files into graphrag.

# %%
def upload_files(
    file_directory: str,
    storage_name: str,
    batch_size: int = 100,
    overwrite: bool = True,
    max_retries: int = 5,
) -> requests.Response | list[Path]:
    """
    Upload files to a blob storage container.

    Args:
    file_directory - a local directory of .txt files to upload. All files must have utf-8 encoding.
    storage_name - a unique name for the Azure storage blob container.
    batch_size - the number of files to upload in a single batch.
    overwrite - whether or not to overwrite files if they already exist in the storage blob container.
    max_retries - the maximum number of times to retry uploading a batch of files if the API is busy.

    NOTE: Uploading files may sometimes fail if the blob container was recently deleted
    (i.e. a few seconds before. The solution "in practice" is to sleep a few seconds and try again.
    """
    url = endpoint + "/data"

    def upload_batch(
        files: list, storage_name: str, overwrite: bool, max_retries: int
    ) -> requests.Response:
        for _ in range(max_retries):
            response = requests.post(
                url=url,
                files=files,
                params={"storage_name": storage_name, "overwrite": overwrite},
                headers=headers,
            )
            # API may be busy, retry
            if response.status_code == 500:
                print("API busy. Sleeping and will try again.")
                time.sleep(10)
                continue
            return response
        return response

    batch_files = []
    accepted_file_types = ["text/plain"]
    filepaths = list(Path(file_directory).iterdir())
    for file in tqdm(filepaths):
        # validate that file is a file, has acceptable file type, has a .txt extension, and has utf-8 encoding
        if (
            not file.is_file()
            or file.suffix != ".txt"
            or magic.from_file(str(file), mime=True) not in accepted_file_types
        ):
            print(f"Skipping invalid file: {file}")
            continue
        # open and decode file as utf-8, ignore bad characters
        batch_files.append(
            ("files", open(file=file, mode="r", encoding="utf-8", errors="ignore"))
        )
        # upload batch of files
        if len(batch_files) == batch_size:
            response = upload_batch(batch_files, storage_name, overwrite, max_retries)
            # if response is not ok, return early
            if not response.ok:
                return response
            batch_files.clear()
    # upload remaining files
    if len(batch_files) > 0:
        response = upload_batch(batch_files, storage_name, overwrite, max_retries)
    return response

# %%
response = upload_files(
    file_directory=file_directory,
    storage_name=storage_name,
    batch_size=100,
    overwrite=True,
)
if not response.ok:
    print(response.text)
else:
    print(response)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 17.12it/s]
# <Response [200]>

# %% [markdown]
# ## Build an Index
#
# After data files have been uploaded, we can construct a knowledge graph by building a search index.

# %%
def build_index(
    storage_name: str,
    index_name: str,
) -> requests.Response:
    """Create a search index.
    This function kicks off a job that builds a knowledge graph index from files located in a blob storage container.
    """
    url = endpoint + "/index"
    request = {"storage_name": storage_name, "index_name": index_name}
    return requests.post(url, params=request, headers=headers)

# %%
response = build_index(storage_name=storage_name, index_name=index_name)
print(response)
if response.ok:
    print(response.text)
else:
    print(f"Failed to submit job.\nStatus: {response.text}")
# Out:
# <Response [200]>
# {"status":"Indexing operation scheduled"}

# %% [markdown]
# ### Check status of an indexing job
#
# Please wait for your index to reach 100 percent completion before continuing on to the next section (running queries). You may rerun the next cell multiple times to monitor status. Note: the indexing speed of graphrag is directly correlated to the TPM quota of the Azure OpenAI model you are using.

# %%
def index_status(index_name: str) -> requests.Response:
    url = endpoint + f"/index/status/{index_name}"
    return requests.get(url, headers=headers)


response = index_status(index_name)
pprint(response.json())
# Out:
# {
#     'status_code': 200,
#     'index_name': 'marpol2-i',
#     'storage_name': 'https://stographrag.blob.core.windows.net/bwgma-kb',
#     'status': 'complete',
#     'percent_complete': 100.0,
#     'progress': '16 out of 16 workflows completed successfully.',
# }

# %% [markdown]
# ## Query
#
# Once an indexing job is complete, the knowledge graph is ready to query. Two types of queries (global and local) are currently supported. We encourage you to try both and experience the difference in responses. Note that query response time is also correlated to the TPM quota of the Azure OpenAI model you are using.

# %%
# a helper function to parse out the result from a query response
def parse_query_response(
    response: requests.Response, return_context_data: bool = False
) -> requests.Response | dict[list[dict]]:
    """
    Prints response['result'] value and optionally
    returns associated context data.
    """
    if response.ok:
        print(json.loads(response.text)["result"])
        if return_context_data:
            return json.loads(response.text)["context_data"]
        return response
    else:
        print(response.reason)
        print(response.content)
        return response

# %%
print(index_name)
# Out:
# marpol2-i

# %% [markdown]
# ### Global Query
#
# Global queries are resource-intensive, but provide good responses to questions that require an understanding of the dataset as a whole.

# %%
# %%time


def global_search(index_name: str | list[str], query: str) -> requests.Response:
    """Run a global query over the knowledge graph(s) associated with one or more indexes"""
    url = endpoint + "/query/global"
    request = {"index_name": index_name, "query": query}
    return requests.post(url, json=request, headers=headers)


global_response = global_search(
    index_name=index_name, query="Summarize the main topics of this data"
)
global_response_data = parse_query_response(global_response, return_context_data=True)
global_response_data
# Out:
# # Overview of the Maritime Industry Data
#
# The dataset provides a comprehensive overview of various aspects of the maritime industry, including infrastructure, regulations, logistics, and labor. Below is a synthesis of the main topics covered in the data.
#
# ## Maritime Industry and Infrastructure
#
# The maritime industry's infrastructure is a complex network that includes marshaling yards, neo-bulk cargo, and motor ships. The U.S. Corps of Engineers and Customs play crucial roles in maintaining and regulating this infrastructure, ensuring trade compliance and the smooth operation of maritime activities [Data: Reports (47, 28)].
#
# ## Maritime Regulations and Trade Zones
#
# U.S. maritime regulations are pivotal for the safe and efficient navigation of vessels. This includes cabotage laws and the use of buoys. Additionally, the establishment of Free Trade Zones (FTZ) is a strategic move to facilitate international trade and enhance the competitiveness of U.S. ports [Data: Reports (19)].
#
# ## Port Authorities and Operations
#
# Port authorities, such as the Georgia Ports Authority and the Charleston Port Authority, oversee port operations and interact with entities like U.S. Customs and labor unions. These authorities are essential for the coordination and management of maritime activities [Data: Reports (14, 41)].
#
# ## Maritime Logistics and Customs
#
# Vessel operators, warehouses, and U.S. Customs are central to maritime logistics. The documentation process, including Way Bills, is critical for tracking and managing cargo movements [Data: Reports (18, 6)].
#
# ## Significant Maritime Hubs
#
# The Port of Halifax and the Port of New Orleans are highlighted as significant maritime hubs. They manage port operations, contribute to maritime knowledge, and are involved in infrastructure projects. The Port of New Orleans is also strategically located and likely associated with the American Association of Port Authorities (AAPA) [Data: Reports (15)].
#
# ## Intermodal Transport
#
# The integration of road and rail transport, particularly the use of tractor-trailers and Trailer On Flat Car (TOFC) methods, is essential for the efficient movement of cargo within the maritime industry [Data: Reports (48)].
#
# ## Labor and Maritime Operations
#
# Longshoremen, marine surveyors, and ship masters are key professionals in maritime operations. The community relies on these individuals for various aspects of maritime labor and operations [Data: Reports (46)].
#
# ## Maritime Supply Chain
#
# The supply chain involves entities such as Chandlers, Captive Cargo Ports, Carriers, and Floats. Cabotage regulations have a significant impact on Carriers and the overall supply chain dynamics [Data: Reports (20)].
#
# ## Steamship Companies and Stevedores
#
# Steamship Companies and Stevedores are part of the interconnected maritime trade network. Tariffs play a role in influencing their operations [Data: Reports (51)].
#
# ## Maritime Commerce Hubs
#
# Harbor and Home Port are crucial in maritime commerce, with relationships with labor unions and grain elevator operations being of particular importance [Data: Reports (32)].
#
# ## Maritime Labor Unions and Shipment
#
# Maritime labor unions, such as the I.L.A. and the I.L.W.U., exert influence on intermodal shipment processes, highlighting the importance of labor in the maritime sector [Data: Reports (34)].
#
# ## Specialized Operations
#
# Heavy Lift and Heavy Hauler operations are specialized aspects of the industry, with the Port of New Orleans playing a strategic role in LASH barge logistics [Data: Reports (33, 38)].
#
# ## Rail Transport Infrastructure
#
# Entities involved in rail transport infrastructure, such as the Railyard, Rubber-Tired Gantry (RTG), Railhead, and Spreader, are discussed, emphasizing their role in the maritime industry [Data: Reports (3)].
#
# ## Container Freight and Standard Units
#
# The Container Freight Station handles standard container units like TEUs and FEUs, which are essential for the standardization and efficiency of cargo handling [Data: Reports (25)].
#
# ## Financial Aspects of Maritime Operations
#
# Anchorage areas and wharfage fees are financial aspects of maritime operations, with the former being crucial for mooring vessels and the latter charged for the use of port facilities during cargo handling [Data: Reports (15)].
#
# In summary, the dataset provides a detailed look at the multifaceted nature of the maritime industry, covering its infrastructure, regulations, logistics, labor, and financial aspects. Each of these components plays a vital role in the efficient and effective functioning of maritime trade and commerce.
# CPU times: user 10.2 ms, sys: 724 μs, total: 10.9 ms
# Wall time: 45.8 s
# {'reports': [{'id': '17',
#    'title': 'Maritime Transport Infrastructure and Operations',
#    'content': "# Maritime Transport Infrastructure and Operations\n\nThis report examines the interconnected roles of vessels, wharfs, tugboats, and the U.S. Army Corps of Engineers within the maritime transport infrastructure, focusing on their functions, relationships, and impact on cargo handling and logistics at Georgia Ports.\n\n## Vessels as the backbone of maritime transport\n\nVessels are central to the maritime transport community, serving as the primary means for moving goods and people across water. Their ability to tie up at wharfs is essential for the loading and unloading of cargo, which is a critical step in the global supply chain. The draft of a vessel determines its suitability for different marine environments, impacting the efficiency and safety of maritime operations [Data: Entities (176); Relationships (181, 184, 196, 199, 200, +more)].\n\n## Wharfs as critical interfaces between sea and land transport\n\nWharfs facilitate the transfer of cargo from vessels to land-based transportation systems, making them vital points in the maritime transport network. They are equipped with infrastructure to support the efficient handling of goods, and their management by port authorities includes the imposition of dockage fees. The proximity of wharfs to warehouses underscores their importance in the logistics chain [Data: Entities (174); Relationships (184, 183, 185, 186)].\n\n## Tugboats' specialized role in port operations\n\nTugboats are specialized vessels that provide essential services in ports, assisting larger vessels with navigation in confined waterways. Their robust construction and powerful engines enable them to perform tasks that are beyond the capability of other vessels, ensuring the safety and efficiency of port operations [Data: Entities (286); Relationships (196, 319)].\n\n## Georgia Ports as a node in the maritime network\n\nGeorgia Ports represent a significant node within the maritime transport network, providing facilities for vessels to dock and manage cargo. The ports' role in the state of Georgia highlights their importance in regional trade and the broader logistics ecosystem [Data: Entities (323); Relationships (201)].\n\n## The U.S. Army Corps of Engineers' role in maritime infrastructure\n\nThe U.S. Army Corps of Engineers is a key federal agency responsible for the construction and maintenance of maritime infrastructure. Their work ensures the navigability of waterways and the functionality of facilities such as docks and levees, which are essential for vessel operations and flood protection. The Corps' involvement in public engineering and environmental stewardship has a direct impact on the maritime transport community [Data: Entities (162, 289); Relationships (173, 197)].\n\n## TEUs as a standard measure for vessel capacity\n\nThe Twenty Foot Equivalent Unit (TEU) is a standardized metric used to quantify the container capacity of vessels. This unit of measurement is crucial for planning and optimizing the loading of cargo, reflecting the importance of efficiency in maritime transport operations [Data: Entities (288); Relationships (156, 198)].",
#    'rank': 7.5,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '17'},
#   {'id': '30',
#    'title': 'Logistics and Infrastructure Community: Freight, FTZ, and Feeder Services',
#    'content': "# Logistics and Infrastructure Community: Freight, FTZ, and Feeder Services\n\nThis community encompasses entities involved in the logistics and infrastructure sector, focusing on the movement, storage, and processing of freight. Key entities include Freight, Foreign Trade Zone (FTZ), Feeder Service, and Fender Piles, which are interconnected through various relationships that facilitate international trade and commerce.\n\n## Freight as the cornerstone of logistics\n\nFreight is the cornerstone of this community, representing the movement and storage of goods across transportation lines. It is directly connected to entities such as Gantry Cranes and Freight Forwarders, which are essential for the loading, unloading, and coordination of cargo movement. The efficiency and effectiveness of Freight operations are vital for the smooth functioning of international trade [Data: Entities (187), Relationships (212, 213)].\n\n## Foreign Trade Zone's strategic role\n\nThe Foreign Trade Zone (FTZ) plays a strategic role in the community by allowing goods to be imported, stored, and manipulated without immediate customs intervention. This facilitates operations such as assembly, manufacturing, and processing, which can significantly reduce costs associated with duties and tariffs. The FTZ's relationship with Freight and Freight Forwarders underscores its importance in the logistics chain [Data: Entities (185), Relationships (209, 210)].\n\n## Feeder Service as a logistics connector\n\nFeeder Service acts as a logistics connector, linking major ports with smaller regional ones. It ensures the efficient movement of goods within a specific geographic area and is integral to the operations of FTZs. The use of Electronic Data Interchange (EDI) by Feeder Services highlights the adoption of technology to manage and track cargo, which is crucial for timely and reliable delivery [Data: Entities (184), Relationships (207, 205)].\n\n## Fender Piles' role in infrastructure integrity\n\nFender Piles, or sacrifice piles, are essential for maintaining the integrity of wharf infrastructure. They absorb the shock of docking ships, protecting the structural pilings of the wharf. Their expendable nature and the need for regular replacement highlight the ongoing maintenance required to support the logistics of Freight handling. Fender Piles are directly related to the operations of Freight and Feeder Services, as they ensure the safe docking of vessels carrying cargo [Data: Entities (186), Relationships (211, 208)].",
#    'rank': 7.5,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '30'},
#   {'id': '16',
#    'title': 'Maritime Compliance and Operations Community',
#    'content': "# Maritime Compliance and Operations Community\n\nThis community is centered around the maritime industry, with a focus on the compliance and operational aspects of barge transportation. The American Bureau of Shipping certifies barges, which are integral to the cargo movement facilitated by marine transportation carriers and supported by infrastructure such as ports and anchorages.\n\n## Barges as a linchpin of maritime cargo transport\n\nBarges play a pivotal role in the maritime industry, particularly in the transportation of significant amounts of cargo through shallow-draft waterways. Their design and functionality make them indispensable for the movement of goods, especially in areas where larger vessels cannot operate effectively. The presence of barges within this community highlights the importance of efficient and reliable cargo transport in the maritime sector [Data: Entities (114)].\n\n## The American Bureau of Shipping's role in maritime safety\n\nThe American Bureau of Shipping is a key entity in ensuring maritime safety and compliance. By certifying barges and other vessels, ABS confirms that they meet the necessary construction and maintenance standards. This certification is crucial for maintaining safety within the maritime industry and for the integrity of maritime operations. ABS's involvement with barges underscores the importance of regulatory compliance in maritime transport [Data: Entities (110), Relationships (107)].\n\n## Marine transportation carriers' utilization of barges\n\nMarine transportation carriers are organizations that manage the return movement of cargo, often in the opposite direction of primary distribution. These carriers rely on barges to transport cargo across waterways, indicating the interdependence between carriers and barges for efficient logistics and distribution. The relationship between marine transportation carriers and barges is essential for understanding the operational dynamics of the maritime industry [Data: Entities (298), Relationships (113)].\n\n## Infrastructure's support for barge operations\n\nMaritime infrastructure, such as ports and anchorages, is vital for the operation of barges. The Port of Halifax is an example of a maritime entity that facilitates the movement of barges for cargo transport. Additionally, barges use anchorages for mooring and are involved in cargo transfer on the apron areas of ports. This infrastructure is integral to the barge's operational cycle, from securing the vessel to the transfer of cargo [Data: Relationships (112, 108, 110)].\n\n## Safety and operational standards in barge certification\n\nThe certification of barges by the American Bureau of Shipping ensures that these vessels adhere to safety and operational standards. This process involves a thorough examination of the barge's construction and maintenance, which is essential for preventing accidents and ensuring the reliability of maritime transport. The ABS's certification of barges is a testament to the industry's commitment to upholding high standards of safety and performance [Data: Relationships (107)].",
#    'rank': 7.5,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '16'},
#   {'id': '29',
#    'title': 'Global Trade and Transportation Network',
#    'content': "# Global Trade and Transportation Network\n\nThis community is centered around the global trade and transportation network, with a focus on the exchange and handling of dry bulk cargo. Key entities include Electronic Data Interchange (EDI), Export Packers, and Elevators, which are interconnected through their roles in enhancing efficiency and competitiveness in international markets.\n\n## EDI as a strategic tool for competitive advantage\n\nElectronic Data Interchange (EDI) is a pivotal system within the transportation industry, designed to streamline the exchange of business information electronically. It is utilized by Port Authorities and feeder services to manage information flow, which is essential for maintaining a competitive edge in international markets. The significance of EDI lies in its ability to facilitate rapid and accurate communication, which is a cornerstone of modern logistics and supply chain management [Data: Entities (181), Relationships (190, 205)].\n\n## Export Packers' role in safeguarding cargo\n\nExport Packers are specialized firms that play a crucial role in the global trade network by ensuring the integrity of export products during transit. Their expertise in packing and securing cargo for ocean voyages is vital for preventing damage and loss, which can have significant economic repercussions. The interaction between Export Packers and EDI systems highlights the integration of physical logistics with information technology to enhance overall efficiency in the export process [Data: Entities (183), Relationships (204)].\n\n## Elevators as critical infrastructure for dry bulk handling\n\nElevators are specialized facilities designed for the storage and handling of dry bulk commodities. They are equipped with advanced infrastructure, including computerized loading systems and inspection rooms, which are essential for the efficient management of cargo such as grain or green coffee. The relationship between Elevators and Export Packers indicates a collaborative interaction in the export process of dry bulk cargo, which is a significant component of global trade [Data: Entities (182), Relationships (206)].\n\n## Dry bulk commodities as a fundamental trade element\n\nDry bulk cargo, which includes a variety of minerals and grains, is a fundamental element of the trade network. The storage and handling of such cargo are facilitated by Elevators, which are designed to manage these commodities effectively. The efficient handling of dry bulk is crucial for the agricultural and mining sectors, impacting food security and industrial supply chains [Data: Entities (178), Relationships (203)].\n\n## Interconnectivity enhancing global trade efficiency\n\nThe interconnectivity between EDI, Export Packers, and Elevators demonstrates a synergistic network that enhances the efficiency of global trade. EDI's role in information exchange, combined with the physical handling and packing expertise of Export Packers and Elevators, creates a streamlined process for international cargo transit. This interconnectedness is vital for the timely and safe delivery of goods across the globe, which in turn affects economic stability and growth [Data: Relationships (190, 204, 205, 206)].",
#    'rank': 7.5,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '29'},
#   {'id': '13',
#    'title': 'Transit Port Logistics Network',
#    'content': "# Transit Port Logistics Network\n\nThe community is centered around the Transit Port, which is a hub for cargo in transit to other destinations. Key entities include TRAMP ships, Transit Sheds, and the process of Transshipment, all of which are integral to the port's operations. The relationships between these entities facilitate the smooth transition of cargo, highlighting the port's role in the global logistics chain.\n\n## Transit Port as a global logistics hub\n\nThe Transit Port is a pivotal entity in the community, serving as a hub for cargoes that are not intended for the local market but are in transit to other destinations. Its role is crucial in the global logistics chain, as it facilitates the transfer of goods to their final endpoints. The port's operations are supported by various entities, including TRAMP ships and Transit Sheds, which are essential for its function as a transfer point [Data: Entities (281), Relationships (316, 317, 318)].\n\n## TRAMP ships' flexible shipping services\n\nTRAMP ships are a type of vessel that operates without a fixed route or schedule, providing adaptable shipping services. These ships are significant to the community as they utilize transit ports like the one in question for their operations. Their flexibility in transport routes underscores the importance of the Transit Port's ability to handle various shipping needs and schedules [Data: Entities (280), Relationships (316)].\n\n## Transit Sheds for short-term cargo storage\n\nTransit Sheds are structures within the Transit Port that provide short-term storage for cargoes, protecting them from weather damage while awaiting further transportation. These sheds are integral to the port's operations, ensuring that goods remain secure during the transition phase of their journey. The relationship between the Transit Port and its Transit Sheds is indicative of the port's role in maintaining the integrity of goods in transit [Data: Entities (282), Relationships (317)].\n\n## Transshipment as a key process\n\nTransshipment is the process of unloading and reloading cargo, sometimes onto different modes of transportation, for transfer to a final destination. This process is frequently carried out at transit ports, highlighting the port's significance as a critical hub in the logistics chain. The ability to efficiently manage transshipment activities is a testament to the Transit Port's technical capabilities and its impact on the flow of global trade [Data: Entities (283), Relationships (318)].\n\n## Tugboats' role within the Transit Port\n\nTugboats are essential for the operations within the Transit Port, assisting ships in maneuvering into and out of the port. Their presence indicates the complexity and scale of operations at the port, as well as the technical capabilities required to manage large vessels and ensure their safe passage. The relationship between tugboats and the Transit Port is a reflection of the port's operational efficiency and safety standards [Data: Relationships (319)].",
#    'rank': 7.5,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '13'},
#   {'id': '42',
#    'title': 'Port Community and Maritime Logistics',
#    'content': "# Port Community and Maritime Logistics\n\nThe community is centered around the port, which is a hub for various maritime logistics activities. It includes entities such as the port authority, port-of-call, project cargo, and local pilots, all of which play a role in the operation and management of maritime traffic and cargo handling. The relationships between these entities highlight the port's importance in global trade and infrastructure projects.\n\n## The port as a central hub for maritime activities\n\nThe port serves as a central hub for maritime activities, with the port authority overseeing its operations. The port's role extends to managing public wharves and properties, ensuring the smooth handling of maritime traffic. The port's significance is further emphasized by its connections to various entities such as reefers, Ro/Ro ships, and stevedores, which are integral to its function in global trade [Data: Entities (240), Relationships (195, 287, 288, 276, +more)].\n\n## Port-of-call's significance in cruise ship itineraries\n\nThe port-of-call is a critical stop for cruise ships, serving as either a transit or destination port. It is a point where passengers can disembark and engage in local activities, which underscores its importance in the tourism sector. The relationship between the port-of-call and cruise ships highlights the port's role in supporting the leisure and travel industry [Data: Entities (245), Relationships (283, 289)].\n\n## Project Cargo's role in international projects\n\nProject Cargo is essential for the construction and completion of significant infrastructure or industrial projects overseas. The port's involvement in transporting these materials underscores its importance in the logistics chain for international assembly projects. The relationship between project cargo and special projects overseas indicates the port's role in facilitating global development initiatives [Data: Entities (246), Relationships (284, 290)].\n\n## Local pilots' contribution to maritime safety\n\nLocal pilots are professionals who provide crucial navigation advice within the port, contributing to maritime safety. Their expertise in local conditions is vital for the safe passage of vessels, particularly in navigating difficult currents and avoiding hidden wrecks. The relationship between local pilots and the port emphasizes their importance in maintaining the safety and efficiency of port operations [Data: Entities (316), Relationships (285)].\n\n## Infrastructure elements within the port\n\nThe port encompasses various infrastructure elements such as piers and quays, which are essential for mooring vessels and handling cargo. These structures facilitate the transfer of goods and passengers, highlighting the port's role in the physical organization of maritime logistics. The presence of pallets within the port also indicates the importance of organization and handling of package cargo, further emphasizing the port's role in supply chain management [Data: Entities (241, 242), Relationships (280, 281, 286)].",
#    'rank': 7.5,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '42'},
#   {'id': '52',
#    'title': 'Port of New Orleans Maritime Logistics',
#    'content': "# Port of New Orleans Maritime Logistics\n\nThe community is centered around the Port of New Orleans and encompasses entities such as towboats, terminals, tank barges, and terminal operators, which are integral to the maritime logistics and transportation of bulk liquids. The relationships between these entities ensure the efficient movement and handling of cargo within the port.\n\n## Towboats as a pivotal element in maritime logistics\n\nTowboats, characterized by their specialized design for pushing barges, are a pivotal element in the maritime logistics at the Port of New Orleans. They facilitate the movement of cargo via waterways, which is essential for the transportation of goods to Mid-America. The versatility and importance of towboats are underscored by their multiple designations, including push boats and line boats [Data: Entities (273); Relationships (253, 311, 312)].\n\n## Terminals as critical cargo handling points\n\nTerminals, or wharfs, serve as critical points for cargo handling activities, including unloading, checking, and transferring cargo. The efficient processing and movement of goods at these locations are vital for the transportation network. The terminal's role is further emphasized by its interactions with other entities such as towboats and tank barges, which transport goods to and from the terminal [Data: Entities (270); Relationships (307, 309, 310)].\n\n## Tank barges' role in liquid cargo transportation\n\nTank barges are specialized vessels designed for the transportation of bulk liquids, including petroleum, chemicals, and liquefied gases. Their role is essential in the maritime industry, as they enable the movement of large quantities of liquid cargo over water. The relationship between tank barges and terminals highlights the importance of these vessels in the cargo handling process [Data: Entities (269); Relationships (304, 309)].\n\n## Terminal operators as managers of cargo activities\n\nTerminal operators are companies responsible for overseeing cargo handling activities at terminals. They ensure that cargo is unloaded, verified, and loaded efficiently and accurately. The symbiotic relationship between terminal operators and terminals is crucial for the logistics chain, as it guarantees the smooth transfer of goods at sea entry or departure points [Data: Entities (271); Relationships (310)].\n\n## Interdependency between entities in the maritime logistics community\n\nThe interdependency between entities such as towboats, terminals, tank barges, and terminal operators at the Port of New Orleans forms a complex network that is essential for maritime logistics. Each entity plays a specific role that contributes to the overall efficiency and effectiveness of cargo transportation and handling. The relationships between these entities ensure that the Port of New Orleans operates as a cohesive and productive hub for maritime commerce [Data: Relationships (253, 307, 304, 311, 309, 310)].",
#    'rank': 7.5,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '52'},
#   {'id': '21',
#    'title': 'Logistics and Distribution Network',
#    'content': "# Logistics and Distribution Network\n\nThis community encompasses entities involved in the transportation and distribution of cargo, including the physical and organizational structures that facilitate the movement of goods. Key entities such as Cargo, Channels of Distribution, Common Carrier, Cartage, and Conference Rate are interconnected, forming a complex network that ensures the efficient delivery of products nationwide.\n\n## Cargo as the foundation of the community\n\nCargo represents the essential goods and products that are transported within this community. It is the core element around which all other entities operate. The efficient and secure movement of cargo is vital for the functioning of the entire distribution network. Cargo's relationship with carriers and channels of distribution indicates its central role in the logistics process [Data: Entities (131), Relationships (134, 135)].\n\n## Channels of Distribution as the backbone\n\nChannels of Distribution are the routes and structures that facilitate the movement of cargo from its origin to its destination. This includes a network of companies and services that ensure goods are delivered efficiently. The involvement of common carriers within these channels highlights the interconnected nature of transportation entities and the importance of coordination among them [Data: Entities (135), Relationships (135, 139)].\n\n## Common Carrier's nationwide reach\n\nCommon carriers are licensed to transport goods or people across the nation, making them a pivotal part of the distribution network. Their ability to move cargo over long distances and across various regions is crucial for maintaining the flow of commerce. The relationship between common carriers and conference rates also points to the regulatory and financial aspects of transportation [Data: Entities (140), Relationships (139, 145)].\n\n## Cartage's role in local distribution\n\nCartage, while a smaller component of the network, is significant for local distribution and the final delivery of goods. It represents the trucking services that connect larger distribution channels to the end consumer. The integration of cartage into the broader channels of distribution emphasizes the importance of local logistics in the overall supply chain [Data: Entities (133), Relationships (137)].\n\n## Conference Rate's impact on pricing\n\nThe conference rate affects the cost of water transportation, which is a key mode of cargo movement. These rates are determined by a conference of carriers, reflecting the collaborative and regulated nature of pricing in the industry. The influence of conference rates on common carriers underlines the financial considerations that are integral to the logistics community [Data: Entities (141), Relationships (145)].",
#    'rank': 7.5,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '21'},
#   {'id': '31',
#    'title': 'Logistics and Cargo Handling Community',
#    'content': "# Logistics and Cargo Handling Community\n\nThis community is centered around the logistics and cargo handling industry, with key entities such as Freight Forwarders, Gantry Cranes, and General Cargo Operations playing pivotal roles in the movement, storage, and handling of goods. These entities are interconnected, working together to facilitate international trade and the efficient transfer of cargo.\n\n## Freight Forwarders as pivotal logistics coordinators\n\nFreight Forwarders are central to this community, coordinating the movement and storage of goods, which is essential for international trade. They work closely with various entities to ensure that cargo reaches its final destination efficiently. Their expertise in navigating complex shipping regulations and customs processes is invaluable, making them a linchpin in the logistics chain [Data: Entities (188); Relationships (214, 213, 209, 215)].\n\n## Gantry Cranes' role in cargo operations\n\nGantry Cranes are crucial for loading and unloading cargo, particularly in the handling of breakbulk and containerized goods. Their presence and use at shipping facilities underline their importance in the operational aspect of cargo transfer, directly impacting the efficiency of cargo handling and the overall speed of logistics operations [Data: Entities (189); Relationships (214, 212, 216, 217)].\n\n## General Cargo Operations' impact on employment\n\nGeneral Cargo Operations, which include the handling of containerized and breakbulk goods, are noted for producing more jobs than bulk handling. This aspect of the community not only contributes to the economy through employment but also through the facilitation of trade and commerce. The handling of general cargo is a labor-intensive process that requires coordination between various entities within the community [Data: Entities (190, 306); Relationships (215, 216, 217)].\n\n## Interplay between Freight Forwarders and Foreign Trade Zones\n\nFreight Forwarders' ability to operate within Foreign Trade Zones (FTZs) allows for the deferral of duty payments, which can significantly reduce costs and increase competitiveness for businesses involved in international trade. This strategic advantage underscores the importance of Freight Forwarders in the community and their role in optimizing trade operations [Data: Relationships (209)].\n\n## The synergy between Freight Forwarders and Gantry Cranes\n\nThe relationship between Freight Forwarders and Gantry Cranes exemplifies the collaborative nature of the logistics and cargo handling community. Freight Forwarders rely on the mechanical efficiency of Gantry Cranes to move cargo, while the cranes are an integral part of the services offered by forwarders. This synergy is essential for the smooth operation of cargo handling and reflects the interdependence of entities within the community [Data: Relationships (214, 212)].",
#    'rank': 7.5,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '31'},
#   {'id': '27',
#    'title': 'Containerization and Terminal Operations Community',
#    'content': "# Containerization and Terminal Operations Community\n\nThis community is centered around the containerization process and the operation of terminals, which are crucial for the handling and transportation of cargo. Key entities include Terminals, Containerization, Container on Flat Car (COFC), and Cranes, all of which are interconnected to facilitate efficient cargo movement.\n\n## Terminals as pivotal hubs for cargo handling\n\nTerminals are essential facilities within this community, providing the infrastructure necessary for cargo handling and storage. They are directly connected to rail access, which is vital for the transportation of goods, particularly using the COFC method. The presence of cranes within terminals underscores their capability to handle large volumes of cargo efficiently. The operation of terminals is supported by the Corps of Engineers, which maintains navigation channels, and by Customs, which collects duties on imported goods [Data: Entities (155); Relationships (165, 166, 163, 164, 162)].\n\n## Containerization as a transformative process\n\nContainerization has revolutionized the shipping industry by standardizing cargo handling and reducing shipping costs. This process is facilitated by the infrastructure provided by terminals and is closely linked to the COFC method, which allows for seamless rail transportation of containers. The synergy between containerization and terminal operations is evident in the mutual benefits they provide to each other, enhancing the overall efficiency of cargo movement [Data: Entities (156); Relationships (163, 160, 167)].\n\n## COFC's role in efficient rail transportation\n\nThe COFC method is a key component of this community, enabling containers to be transported efficiently by rail. This method leverages the simplicity of loading and unloading containers without additional equipment, such as a chassis, and is a part of the broader containerization process. Terminals that have direct rail access are particularly suited to utilize the COFC method, which underscores the interdependence of entities within this community [Data: Entities (157); Relationships (164, 167)].\n\n## Cranes' critical function in cargo operations\n\nCranes are vital equipment within terminals, with the capacity to handle significant cargo weights and reach across vessels. Their role is indispensable in the loading and unloading process, directly impacting the efficiency of terminal operations. The technical capabilities of cranes, including their lifting capacity and outreach, are tailored to meet the demands of modern cargo handling, thereby supporting the containerization process [Data: Entities (154); Relationships (162)].\n\n## Inter-agency collaboration and compliance\n\nThe operation of terminals involves collaboration with various agencies, such as the Corps of Engineers and Customs. The Corps of Engineers plays a crucial role in maintaining navigation channels, which is essential for the smooth operation of terminals. Customs is responsible for the collection of duties, indicating the legal compliance aspect of terminal operations. These relationships highlight the importance of inter-agency collaboration in ensuring the functionality and compliance of the terminal operations within this community [Data: Relationships (165, 166)].",
#    'rank': 7.5,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '27'},
#   {'id': '35',
#    'title': 'Interchange and Hostler Operations',
#    'content': "# Interchange and Hostler Operations\n\nThe community is centered around the Interchange, a critical hub for containerized cargo handling, with Hostlers playing a vital role in the efficient movement of containers within the yard. The Interchange is integral to the intermodal shipment process, and Hostlers facilitate the cargo's transition at these points.\n\n## Interchange as a pivotal logistics hub\n\nInterchange serves as an essential node in the logistics network, acting as a central point for the coordination of containerized cargo movement. It is a critical part of the supply chain, facilitating the transfer of goods between different transportation modes. The efficient functioning of Interchange points is vital for minimizing delays and ensuring the timely delivery of goods, which has a significant impact on the economy and trade. [Data: Entities (198), Relationships (226)]\n\n## Hostler's role in container yard operations\n\nHostlers, also known as hustlers, are key personnel within the container yard, responsible for the relocation of cargo containers using tractors. Their role is crucial for maintaining the flow of goods at the Interchange, as they ensure that containers are moved safely and efficiently to their respective locations. The performance of Hostlers directly affects the operational efficiency of the Interchange, highlighting their importance in the logistics process. [Data: Entities (197), Relationships (225)]\n\n## Interchange's impact on intermodal shipment\n\nThe Interchange is a key component in the intermodal shipment process, where cargo is transferred between different modes of transportation such as ships, trains, and trucks. This process is essential for global trade, as it allows for the seamless movement of goods across long distances. The effectiveness of Interchange operations can significantly influence the speed and reliability of cargo delivery, which in turn affects businesses and consumers alike. [Data: Relationships (226)]\n\n## Hostler-Interchange interaction\n\nThe interaction between Hostlers and the Interchange is a symbiotic one, where Hostlers are responsible for the internal movement of containers that are crucial for the Interchange's operations. This relationship underscores the dependency of the Interchange on the Hostlers' ability to perform their duties effectively. Any disruption in the Hostler's work can lead to bottlenecks at the Interchange, affecting the broader logistics network. [Data: Relationships (225)]",
#    'rank': 7.5,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '35'},
#   {'id': '45',
#    'title': 'Maritime Industry: Surveyors, Masters, and Manifests',
#    'content': "# Maritime Industry: Surveyors, Masters, and Manifests\n\nThe community is centered around the Maritime Industry, with key entities including Marine Surveyors, Masters, and the use of Manifests. These entities are interconnected, with Marine Surveyors and Masters operating within the industry and the Manifest being a crucial document maintained by the Master. The relationships indicate a structured hierarchy and adherence to industry standards.\n\n## Marine Surveyors' pivotal role in maritime operations\n\nMarine Surveyors are integral to the Maritime Industry, ensuring the safety and compliance of vessels and their cargo. They inspect ships and assess cargo, which is essential for maintaining standards and preventing maritime accidents. Their expertise contributes to the industry's reputation and operational efficiency [Data: Entities (223), Relationships (262, 255)].\n\n## Masters' authority and responsibility\n\nMasters, or Captains, hold the highest authority on ships, responsible for navigation, crew management, and adherence to laws. Their decisions directly affect the safety of the ship and crew, as well as the efficiency of shipping operations. The Master's role is critical in crisis situations and in ensuring compliance with international maritime regulations [Data: Entities (226), Relationships (264, 263)].\n\n## Manifests as a key document in maritime logistics\n\nThe Manifest is a vital document listing a ship's cargo, maintained by the Master. It is used by various stakeholders, including Longshoremen, for loading and unloading operations. The accuracy and integrity of the Manifest are crucial for customs, inventory management, and legal compliance, reflecting the organized nature of maritime logistics [Data: Entities (225), Relationships (258, 263)].\n\n## Interactions between Marine Surveyors and Masters\n\nMarine Surveyors often interact with Masters, reporting on the condition of ships and cargo. This relationship is fundamental to maintaining operational standards and ensuring that vessels are fit for purpose. The collaboration between Surveyors and Masters is indicative of the industry's commitment to safety and quality control [Data: Relationships (261)].\n\n## Inspection of LASH barges by Marine Surveyors\n\nMarine Surveyors inspect LASH barges as part of their duties, which is indicative of their broad scope of work within the industry. LASH barges are critical for the transport of goods, and their condition directly impacts the efficiency and safety of cargo transportation. The Surveyors' role in inspecting these barges underscores their importance in the maritime supply chain [Data: Relationships (255)].",
#    'rank': 7.5,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '45'},
#   {'id': '50',
#    'title': 'Maritime Shipping Network: NVOCCs, Ocean Carriers, and Steamship Agents',
#    'content': "# Maritime Shipping Network: NVOCCs, Ocean Carriers, and Steamship Agents\n\nThis community is centered around the maritime shipping industry, with key entities including NVOCCs, Ocean Carriers, and Steamship Agents. These entities work in concert to facilitate the transportation of goods across the sea, with each playing a specialized role in the logistics and operations of maritime shipping.\n\n## The pivotal role of Steamship Agents\n\nSteamship Agents are crucial in the maritime industry, acting as the linchpin between various entities such as steamship companies, stevedores, and the ships themselves. They ensure efficient port operations, which is vital for maintaining the shipping schedules and services of steamship companies [Data: Entities (238); Relationships (278, 279, 277)].\n\n## Ocean Carriers as the backbone of sea transportation\n\nOcean Carriers are central to the maritime shipping network, transporting goods and passengers across the sea. They rely on Steamship Agents for port representation and are integral to the operations of NVOCCs and the supply chain, including interactions with chandlers and the carriage of neo-bulk cargo [Data: Entities (235); Relationships (272, 273, 138, 271)].\n\n## NVOCCs facilitating access for smaller shippers\n\nNVOCCs play a key role by providing smaller shippers with access to shipping services, consolidating freight to optimize space usage on ocean carriers. They are a vital part of the maritime industry, ensuring that smaller volumes of cargo can be efficiently transported alongside larger consignments [Data: Entities (233); Relationships (270, 269)].\n\n## Evolution of the term 'Steamship'\n\nThe term 'Steamship' has evolved from its historical reference to steam-powered vessels to now include modern diesel-fueled cargo ships. Despite the change in technology, the term persists in some contexts, reflecting the industry's heritage and its adaptation to modern propulsion methods [Data: Entities (260); Relationships (273, 296)].\n\n## Interdependencies within the maritime shipping community\n\nThe relationships between the entities in this community highlight the interdependencies that are essential for the smooth functioning of maritime shipping. Steamship Agents, Ocean Carriers, and NVOCCs must work closely together to ensure the efficient transport of goods, which is a cornerstone of global trade [Data: Relationships (278, 272, 279, 269)].",
#    'rank': 7.5,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '50'},
#   {'id': '24',
#    'title': 'Container Logistics and Consolidation Community',
# ...
#    'rank': 7.5,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '3'},
#   {'id': '41',
#    'title': 'Charleston Port Authority and Maritime Operations',
#    'content': "# Charleston Port Authority and Maritime Operations\n\nThe Charleston Port Authority is a pivotal entity in the maritime community of Charleston, South Carolina, overseeing a network of operations that include stevedores, quays, and dredging activities. This community is integral to the facilitation of maritime trade and logistics, with the Port Authority at the helm of managing the port's infrastructure and labor.\n\n## Port Authority as the central managing body\n\nThe Port Authority is the central managing body of the port's operations, with a high degree of interconnectedness with other entities such as docks, wharves, and stevedores. It ensures the efficient handling of cargo and vessel accommodation, which is vital for the economic vitality of Charleston. The authority's role extends to the management of dockage fees and maintenance of navigable waterways [Data: Entities (175); Relationships (195, 182, 183, 192, 194, +more)].\n\n## Stevedore's role in cargo handling\n\nStevedores are crucial for the loading and unloading of cargo, working in tandem with the Port Authority and longshore labor. Their operations are essential for the transfer of goods, impacting the efficiency of the port's overall cargo movement. The collaboration between the Port Authority and stevedores reflects a partnership that is fundamental to the port's functionality [Data: Entities (237); Relationships (276, 192, 275)].\n\n## Quay as a structural asset\n\nThe quay is a key structural asset within the port, facilitating the docking of ships and the handling of cargo. Its administration by the Port Authority underscores the importance of such infrastructure in the overall port operations. The quay's role is indicative of the physical requirements necessary for maritime logistics [Data: Entities (247); Relationships (286, 193)].\n\n## Dredging for navigability\n\nDredging is a critical maintenance activity overseen by the Port Authority to ensure waterways remain navigable for vessels. The dredge's role in removing silt maintains the harbor's depth, which is essential for the safe passage and docking of ships. This process is indicative of the ongoing efforts required to sustain the port's operational capabilities [Data: Entities (177); Relationships (188, 202)].\n\n## Economic implications of duty collection\n\nThe collection of duty on imported merchandise by the Port Authority has significant economic implications. It represents a source of revenue for the government and affects the cost of goods entering the domestic market. The Port Authority's involvement in duty collection highlights its multifaceted role in both operations and fiscal responsibilities [Data: Entities (180); Relationships (189)].\n\n## Charleston's strategic maritime position\n\nCharleston, South Carolina's strategic position as a hub for maritime activities is reinforced by the comprehensive facilities and services provided by the Port Authority. The city's economic health is closely tied to the efficient operation of its port, which serves as a gateway for international trade and a significant employer for the region [Data: Entities (236); Relationships (191, 274)].",
#    'rank': 7.5,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '41'},
#   {'id': '39',
#    'title': 'LASH Barges and Towboats Maritime Operations',
#    'content': "# LASH Barges and Towboats Maritime Operations\n\nThe community is centered around the maritime operations of LASH barges and towboats, with a focus on their roles in cargo transportation and the relationships with the Port of New Orleans and marine surveyors. LASH barges are specialized for being lifted into ocean-going ships, while towboats are essential for assembling barges into tows.\n\n## LASH Barges' Specialized Function\n\nLASH barges are specialized maritime vessels that play a crucial role in the global shipping industry. They are designed to be lifted into larger ocean-going ships, allowing for efficient transport and overseas discharge. Their use at the Port of New Orleans for loading cargo onto ships for export underlines their importance in facilitating international trade and logistics. [Data: Entities (219), Relationships (248)]\n\n## Towboats' Distinct Role from Tugboats\n\nTowboats are distinguished from tugboats by their specific use for pushing barges. This distinction is important for understanding the operational dynamics within the maritime community, as towboats are responsible for assembling LASH barges into tows. These tows are then transported to various ports, highlighting the towboats' essential role in the movement of goods along inland waterways and to international destinations. [Data: Entities (220), Relationships (256)]\n\n## Interdependency of LASH Barges and Towboats\n\nThe relationship between LASH barges and towboats is symbiotic and vital for the maritime transportation network. Towboats are responsible for assembling LASH barges into tows, which are then transported to various ports. This interdependency is a key aspect of the community's structure, emphasizing the coordinated efforts required for successful maritime operations. [Data: Relationships (254)]\n\n## Marine Surveyors' Role in Maintaining Standards\n\nMarine surveyors are integral to the community by ensuring the seaworthiness and condition of LASH barges. Their inspections and assessments are crucial for maintaining safety standards and operational efficiency. The involvement of marine surveyors also indicates a level of oversight and quality control within the community, which is essential for the prevention of maritime accidents and environmental incidents. [Data: Relationships (255)]\n\n## Port of New Orleans as a Strategic Hub\n\nThe Port of New Orleans serves as a strategic hub within this community, facilitating the export of cargo loaded onto ocean-going ships. The use of LASH barges at this port signifies its role in the larger network of global trade and the importance of efficient cargo handling and transportation systems. The port's ranking in the relationships indicates its prominence and the volume of activity associated with LASH barges. [Data: Relationships (248)]",
#    'rank': 7.5,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '39'},
#   {'id': '25',
#    'title': 'Container Freight Station and Standard Container Units',
#    'content': "# Container Freight Station and Standard Container Units\n\nThis community is centered around the Container Freight Station, which plays a pivotal role in the handling of standard container units, specifically TEUs and FEUs. These units are integral to the shipping industry, providing standardized measurements for vessel capacity and cargo transport.\n\n## TEU as a universal shipping measure\n\nThe Twenty-foot Equivalent Unit (TEU) is a fundamental measure in the shipping industry, providing a standardized method for calculating container volume. Its widespread use allows for the efficient organization and movement of goods on a global scale. TEUs are also used to measure the capacity of vessels, indicating their importance in maritime logistics [Data: Entities (148); Relationships (156)].\n\n## Container Freight Station's role in cargo handling\n\nContainer Freight Stations are crucial for the 'stuffing' and 'stripping' processes of cargo containers, which are essential for the efficient handling and movement of goods via rail. These facilities serve as a hub for the transfer of cargo, ensuring that containers are properly loaded and unloaded for transportation [Data: Entities (150); Relationships (152, 155)].\n\n## FEU as an alternative container measurement\n\nThe Forty-foot Equivalent Unit (FEU) is another standard container dimension used in cargo transport. While it is less frequently mentioned than the TEU, it represents a larger container size and is also handled by Container Freight Stations. The FEU's role complements that of the TEU in providing options for cargo size and transportation efficiency [Data: Entities (149); Relationships (157)].\n\n## Interrelation of TEUs and Container Freight Stations\n\nThe interrelation between TEUs and Container Freight Stations is evident in the stuffing and stripping processes. Container Freight Stations are designed to accommodate the dimensions of TEUs, which further underscores the standardized nature of cargo handling in the industry. This relationship is vital for maintaining the flow of goods and the overall efficiency of the shipping sector [Data: Relationships (155)].\n\n## FEUs at Container Freight Stations\n\nFEUs are handled alongside TEUs at Container Freight Stations, indicating the versatility of these facilities in managing different container sizes. The ability to handle both TEUs and FEUs is indicative of the adaptability and capacity of Container Freight Stations to serve the diverse needs of the shipping industry [Data: Relationships (157)].",
#    'rank': 7.5,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '25'},
#   {'id': '34',
#    'title': 'Maritime Labor Unions and Intermodal Shipment',
#    'content': "# Maritime Labor Unions and Intermodal Shipment\n\nThis community is centered around two major labor unions, the I.L.A. and the I.L.W.U., which are integral to the intermodal shipment process across the United States. These entities are interconnected with various aspects of maritime and transportation logistics, including Home Ports, Harbors, and standards set by the ISO.\n\n## I.L.A.'s influence on East and Gulf Coast maritime labor\n\nThe International Longshoremen's Association (I.L.A.) is a pivotal entity in the maritime industry, representing workers along the East and Gulf Coasts of the United States. The I.L.A.'s involvement in intermodal shipment operations is significant, as it handles labor-related tasks that are essential for the efficient movement of goods using multiple transportation modes. The union's presence in Home Ports and Harbors suggests a widespread influence on maritime labor in these regions [Data: Entities (199); Relationships (227, 223, 220)].\n\n## I.L.W.U.'s role in West Coast maritime operations\n\nThe International Longshore and Warehouse Union (I.L.W.U.) mirrors the I.L.A.'s role on the West Coast, representing workers in the longshore and warehouse industries. The I.L.W.U.'s involvement in intermodal shipments is crucial for the smooth transition of goods between transportation modes, highlighting its importance in the logistics and supply chain of the West Coast. The union's potential representation in Home Ports indicates a strong regional presence [Data: Entities (200); Relationships (228, 224)].\n\n## Intermodal Shipment as a key logistics process\n\nIntermodal Shipment is a central process in this community, involving the use of various transportation modes to move cargo efficiently. The process is supported by specialized facilities like IMX yards and adheres to standards set by the ISO, which underscores its systemic importance. The involvement of both I.L.A. and I.L.W.U. in this process indicates the critical role of labor unions in ensuring the effectiveness of intermodal shipments [Data: Entities (201); Relationships (229, 230, 226)].\n\n## IMX yards' role in the intermodal exchange\n\nIMX yards are specialized facilities that facilitate the intermodal exchange, a vital phase in the Intermodal Shipment process. These yards ensure the efficient transfer of containers between different transportation modes, which is fundamental to the logistics industry. The close relationship between Intermodal Shipment and IMX highlights the operational importance of these yards [Data: Relationships (229)].\n\n## ISO standards' impact on transportation efficiency\n\nThe International Organization for Standardization (ISO) sets standards that are crucial for the intermodal shipment process. These standards, particularly for containers, enable the seamless transfer of goods across different transportation modes, contributing to the overall efficiency and reliability of the supply chain. The adherence to ISO standards by entities involved in Intermodal Shipment reflects the importance of regulatory compliance in the industry [Data: Relationships (230)].",
#    'rank': 7.5,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '34'},
#   {'id': '15',
#    'title': 'Maritime Trade Hubs: Port of Halifax and The Port of New Orleans',
#    'content': "# Maritime Trade Hubs: Port of Halifax and The Port of New Orleans\n\nThis report examines the interconnectedness of two major North American ports, the Port of Halifax and The Port of New Orleans, and their relationships with other maritime entities such as AAPA, ABS, and the concept of wharfage fees. These ports are central to maritime trade and have educational contributions to the sector.\n\n## The Port of Halifax's multifaceted role\n\nThe Port of Halifax emerges as a significant entity with a comprehensive role in maritime trade and education. It manages port operations and contributes to maritime knowledge, indicating its influence beyond mere logistics. The port's relationship with barges and the American Bureau of Shipping (ABS) underscores its operational and safety oversight [Data: Entities (296); Relationships (112, 330)].\n\n## The Port of New Orleans' strategic importance\n\nThe Port of New Orleans is a pivotal maritime hub known for its cargo handling capabilities and its strategic location in Louisiana. It is involved in infrastructure projects with the Corps of Engineers and is likely associated with the American Association of Port Authorities (AAPA), reflecting its active role in the maritime community and its influence on industry standards [Data: Entities (294); Relationships (187, 169, 327)].\n\n## AAPA's connectivity with ports\n\nAAPA appears to be a central organization connecting various ports, including The Port of New Orleans and the Port of Halifax. This association suggests a network of collaboration and shared standards among member ports, which could impact maritime trade policies and practices [Data: Entities (324); Relationships (327, 329, 332)].\n\n## Anchorage and its economic implications\n\nAnchorage areas within harbors, such as those likely present at The Port of New Orleans, are essential for mooring vessels. The associated port charges reflect the economic activities and the logistical considerations of maritime operations. The relationship between anchorage and barges also highlights the operational dynamics within harbors [Data: Entities (111); Relationships (108, 109)].\n\n## Wharfage fees as a financial aspect of maritime operations\n\nWharfage fees represent a critical financial aspect of maritime operations, charged by ports like The Port of New Orleans and the Port of Halifax for cargo handling. This fee system is integral to the economic model of port operations, compensating for the use of facilities and services provided during the loading or unloading process [Data: Entities (321); Relationships (326, 331, 186)].",
#    'rank': 7.5,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '15'}],
#  'entities': [],
#  'relationships': [],
#  'claims': []}

# %% [markdown]
# ### Local Query
#
# Local search queries are best suited for narrow-focused questions that require an understanding of specific entities mentioned in the documents (e.g. What are the healing properties of chamomile?)

# %%
# %%time


def local_search(index_name: str | list[str], query: str) -> requests.Response:
    """Run a local query over the knowledge graph(s) associated with one or more indexes"""
    url = endpoint + "/query/local"
    request = {"index_name": index_name, "query": query}
    return requests.post(url, json=request, headers=headers)


# perform a local query
local_response = local_search(
    index_name=index_name, query="Who are the primary actors in these communities?"
)
local_response_data = parse_query_response(local_response, return_context_data=True)
local_response_data
# Out:
# # Landlord Port Labor Community Report
#
# ## Overview
# The Landlord Port Labor Community is a complex network of entities that play pivotal roles in the operations and management of port infrastructure. This community is characterized by a diverse array of actors, including labor unions, specialized organizations, and support service companies, all of which contribute to the functionality and efficiency of port activities.
#
# ## Primary Actors
#
# ### Landlord Port
# The Landlord Port stands as the central infrastructure entity in this community. It is responsible for leasing wharves to terminal operators, which is a critical aspect of the port's operational model [Data: Entities (207)].
#
# ### Labor Unions
# Several labor unions are key actors within the community, representing the workforce and advocating for their rights and interests:
# - **General Longshore Workers**: A local union representing various laborers within ports [Data: Entities (309)].
# - **Seafarer’s International Union**: Represents seafarers' interests at the Landlord Port [Data: Relationships (238)].
# - **National Maritime Union**: Advocates for maritime workers at landlord ports [Data: Relationships (239)].
# - **Marine Engineers’ Beneficial Association**: Represents marine engineers, crucial for the maintenance and operation of port machinery [Data: Relationships (240)].
# - **Teamsters**: A diverse labor union involved in cargo transportation and handling [Data: Entities (213); Relationships (241)].
#
# ### Specialized Organizations
# Organizations with specialized roles in cargo management and operations are also primary actors:
# - **Dray Clerks, Weighers and Samplers**: Specialize in cargo management and unloading operations [Data: Relationships (237)].
# - **Unloaders of Freight Cars and Barges**: Handle the unloading of freight cars and barges [Data: Relationships (236)].
#
# ### Support Service Companies
# - **Launch Service Companies**: Provide critical water-taxi services to ships at anchor, facilitating the movement of personnel and supplies [Data: Entities (215); Relationships (242)].
#
# ### Governing and Regulatory Bodies
# - **Board of Commissioners**: Governs the port authority and oversees operations [Data: Entities (116)].
# - **Governments of the States Parties**: Authorities of countries that have agreed to conventions and approve the adequacy of reception facilities for oil tankers [Data: Entities (58)].
#
# ### Operational Entities
# - **Local Pilots**: Professionals who provide navigation advice to ships [Data: Entities (316)].
# - **Stevedores**: Labor management companies that facilitate cargo transfer [Data: Entities (263)].
#
# ## Conclusion
# The Landlord Port Labor Community is sustained by the interplay of these primary actors, each fulfilling their specialized roles to ensure the smooth operation of port activities. The labor unions and specialized organizations are particularly significant in representing the workforce and ensuring the efficiency of cargo handling, while support service companies and governing bodies provide the necessary infrastructure and regulatory oversight.
# CPU times: user 9.57 ms, sys: 0 ns, total: 9.57 ms
# Wall time: 19.6 s
# {'reports': [{'id': '37',
#    'title': 'Landlord Port Labor Community',
#    'content': "# Landlord Port Labor Community\n\nThe community is centered around the Landlord Port model, which involves various labor unions and organizations that represent the interests of workers and professionals in port operations. These entities are interconnected through their roles in managing, operating, and servicing the port infrastructure and its activities.\n\n## Landlord Port as a pivotal infrastructure entity\n\nLandlord Port is a key entity in this community, serving as the foundational infrastructure for port operations. It leases wharves to terminal operators, allowing for specialization in cargo handling and transportation. The port's management model is crucial for the efficiency and effectiveness of global trade logistics. The presence of multiple labor unions within the port suggests a complex network of relationships that are essential for maintaining operational harmony and addressing workers' rights [Data: Entities (207), Relationships (235, 237, 244, 236, +more)].\n\n## Influence of labor unions on Landlord Port operations\n\nLabor unions such as the General Longshore Workers, Seafarer’s International Union, and National Maritime Union play a significant role in representing workers' interests at the Landlord Port. These unions are instrumental in negotiating working conditions, wages, and ensuring fair treatment of port workers. Their involvement is indicative of the collective bargaining power within the port community and the potential for labor actions to impact port operations [Data: Entities (209, 309, 210, 211, +more), Relationships (235, 244, 238, 239, +more)].\n\n## Specialized roles of organizations within the port community\n\nOrganizations such as Dray Clerks, Weighers and Samplers, and Unloaders of Freight Cars and Barges have specialized roles in cargo management and unloading operations. Their expertise ensures the accuracy and efficiency of cargo handling, which is vital for the smooth functioning of the Landlord Port. The interdependence of these entities on the port's infrastructure underscores the collaborative nature of port operations [Data: Entities (209, 208), Relationships (237, 236)].\n\n## Technical and professional expertise of Marine Engineers’ Beneficial Association\n\nThe Marine Engineers’ Beneficial Association represents marine engineers who are likely involved in the maintenance and operation of port machinery at the Landlord Port. Their technical expertise is critical for the upkeep of the port's infrastructure and the safety of operations. The association's advocacy for its members' professional interests highlights the importance of skilled labor in the maritime industry [Data: Entities (212), Relationships (240)].\n\n## Teamsters' role in cargo transportation and handling\n\nThe Teamsters union represents a diverse group of workers, including those involved in the transportation and handling of cargo at the Landlord Port. Their role is essential for the inland distribution of goods and the overall supply chain. The presence of the Teamsters within the port community reflects the interconnectedness of various modes of transportation and the significance of labor representation across sectors [Data: Entities (213), Relationships (241)].\n\n## Launch Service companies as essential support entities\n\nLaunch Service companies provide critical water-taxi services to ships at anchor, facilitating the movement of personnel and supplies. Their operation within the Landlord Port is indicative of the ancillary services that support the core activities of cargo handling and shipping. These companies are an integral part of the maritime logistics ecosystem, ensuring the continuity of port operations [Data: Entities (215), Relationships (242)].",
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '37'}],
#  'entities': [{'id': '58',
#    'entity': '"GOVERNMENTS OF THE STATES PARTIES"',
#    'description': '"Governments of the States Parties are the authorities of the countries that have agreed to the present Convention and approve the adequacy of reception facilities for oil tankers."',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '58'},
#   {'id': '309',
#    'entity': '"GENERAL LONGSHORE WORKERS"',
#    'description': '"The General Longshore Workers is a local union within ports that represents various laborers."',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '309'},
#   {'id': '311',
#    'entity': '"SACK-SEWERS, SWEEPERS, WATER BOYS AND COOPERS"',
#    'description': '"Sack-sewers, Sweepers, Water boys and Coopers is a local union within ports that represents laborers in specialized roles."',
#    'number of relationships': '0',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '311'},
#   {'id': '316',
#    'entity': '"LOCAL PILOTS"',
#    'description': '"Local pilots are professionals who board ships to provide navigation advice to the captain and navigator about local conditions such as difficult currents and hidden wrecks."',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '316'},
#   {'id': '68',
#    'entity': '"SURVEYS"',
#    'description': '',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '68'},
#   {'id': '256',
#    'entity': '"VEHICLES"',
#    'description': '',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '256'},
#   {'id': '116',
#    'entity': '"BOARD OF COMMISSIONERS"',
#    'description': 'The Board of Commissioners is the governing body of a port authority. Its members may either be elected or appointed to serve on the board for several years. This board is responsible for overseeing the operations and making decisions that affect the port authority.',
#    'number of relationships': '5',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '116'},
#   {'id': '310',
#    'entity': '"CLERKS AND CHECKERS"',
#    'description': '"Clerks and Checkers is a local union within ports that represents workers responsible for clerical tasks related to cargo handling."',
#    'number of relationships': '0',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '310'},
#   {'id': '213',
#    'entity': '"TEAMSTERS"',
#    'description': 'The Teamsters, formally known as the International Brotherhood of Teamsters, is a labor union that represents a diverse membership of blue-collar and professional workers across both the public and private sectors.',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '213'},
#   {'id': '56',
#    'entity': '"STATE PARTY"',
#    'description': '"State Party refers to a country that has agreed to and is bound by the terms of the present Convention, which includes regulations on oil pollution prevention."',
#    'number of relationships': '2',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '56'},
#   {'id': '140',
#    'entity': '"COMMON CARRIER"',
#    'description': '"Common carriers are trucking, railroad, or barge lines licensed to transport goods or people nationwide."',
#    'number of relationships': '2',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '140'},
#   {'id': '222',
#    'entity': '"LONGSHOREMEN"',
#    'description': "Longshoremen, also known as stevedores, are dock workers responsible for loading and unloading cargo from ships. Their duties may also extend to performing administrative tasks associated with the cargo's loading or unloading process. While many longshoremen are members of labor unions, there are also non-unionized workers in the field. Regardless of their union status, these workers play a crucial role in the maritime industry, ensuring the smooth transfer of goods across the world's ports.",
#    'number of relationships': '5',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '222'},
#   {'id': '274',
#    'entity': '"MID-AMERICA"',
#    'description': '"Mid-America refers to the central region of the United States, which is a destination for cargo delivered from the Port of New Orleans."',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '274'},
#   {'id': '254',
#    'entity': '"SPECIAL PROJECT OVERSEAS"',
#    'description': '',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '254'},
#   {'id': '215',
#    'entity': '"LAUNCH SERVICE"',
#    'description': '"Companies that provide water-taxi services to ships at anchor."',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '215'},
#   {'id': '98',
#    'entity': '"SHIPS"',
#    'description': '"Ships are referred to as entities that must comply with certain standards and regulations to prevent oil pollution."',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '98'},
#   {'id': '207',
#    'entity': '"LANDLORD PORT"',
#    'description': 'Landlord Port is a port management model where the port authority is responsible for constructing the wharves and then renting or leasing them to terminal operators. These operators, which can include stevedoring companies, invest in cargo-handling equipment, hire labor, and negotiate contracts with ocean carriers to handle cargo. This arrangement allows for specialization where the port authority focuses on the infrastructure and the terminal operators concentrate on the logistics of cargo handling and transportation.',
#    'number of relationships': '10',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '207'},
#   {'id': '253',
#    'entity': '"CRUISE SHIP"',
#    'description': '',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '253'},
#   {'id': '263',
#    'entity': '"STEVEDORES"',
#    'description': 'Stevedores are labor management companies that specialize in providing equipment and hiring workers, commonly referred to as stevedores or longshoremen, to facilitate the transfer of cargo between ships and docks. In addition to their primary role in cargo handling, they often serve as terminal operators, overseeing the operations at the docks where cargo handling takes place. Their responsibilities encompass both the management of labor and the provision of necessary equipment for efficient cargo transfer.',
#    'number of relationships': '5',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '263'},
#   {'id': '324',
#    'entity': '"AAPA"',
#    'description': '"AAPA refers to the American Association of Port Authorities, an organization that may be contacted for advertising or other services."',
#    'number of relationships': '3',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '324'}],
#  'relationships': [{'id': '241',
#    'source': '"LANDLORD PORT"',
#    'target': '"TEAMSTERS"',
#    'description': '"Teamsters may represent workers at landlord ports who are involved in the transportation and handling of cargo."',
#    'weight': '1.0',
#    'rank': '11',
#    'links': '3',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '241'},
#   {'id': '242',
#    'source': '"LANDLORD PORT"',
#    'target': '"LAUNCH SERVICE"',
#    'description': '"Launch service companies operate at landlord ports, providing transportation to ships at anchor."',
#    'weight': '1.0',
#    'rank': '11',
#    'links': '3',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '242'},
#   {'id': '244',
#    'source': '"LANDLORD PORT"',
#    'target': '"GENERAL LONGSHORE WORKERS"',
#    'description': '"The General Longshore Workers union may represent workers at a landlord port, where the port authority leases wharves to terminal operators."',
#    'weight': '1.0',
#    'rank': '11',
#    'links': '3',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '244'},
#   {'id': '249',
#    'source': '"PORT OF NEW ORLEANS"',
#    'target': '"LONGSHOREMEN"',
#    'description': '"Longshoremen work at ports like the Port of New Orleans to load and unload cargo from ships."',
#    'weight': '1.0',
#    'rank': '13',
#    'links': '2',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '249'},
#   {'id': '250',
#    'source': '"PORT OF NEW ORLEANS"',
#    'target': '"MID-AMERICA"',
#    'description': '"The Port of New Orleans delivers cargo to Mid-America, indicating a logistical and transportation relationship."',
#    'weight': '1.0',
#    'rank': '9',
#    'links': '2',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '250'},
#   {'id': '51',
#    'source': '"INTERNATIONAL OIL POLLUTION PREVENTION CERTIFICATE"',
#    'target': '"GOVERNMENTS OF THE STATES PARTIES"',
#    'description': '"The Governments of the States Parties approve the adequacy of reception facilities, which is a condition for the endorsement of the International Oil Pollution Prevention Certificate."',
#    'weight': '1.0',
#    'rank': '16',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '51'},
#   {'id': '243',
#    'source': '"LANDLORD PORT"',
#    'target': '"LASH"',
#    'description': '"LASH ships may utilize landlord ports for the loading and unloading of their barges."',
#    'weight': '1.0',
#    'rank': '13',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '243'},
#   {'id': '235',
#    'source': '"LABOR UNION"',
#    'target': '"LANDLORD PORT"',
#    'description': '"Labor Unions may represent the workers who are employed at Landlord Ports, affecting working conditions and wages."',
#    'weight': '1.0',
#    'rank': '12',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '235'},
#   {'id': '285',
#    'source': '"PORT"',
#    'target': '"LOCAL PILOTS"',
#    'description': '"Local pilots operate within a port, providing navigation advice to ships docked or passing through."',
#    'weight': '1.0',
#    'rank': '12',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '285'},
#   {'id': '236',
#    'source': '"LANDLORD PORT"',
#    'target': '"UNLOADERS OF FREIGHT CARS AND BARGES"',
#    'description': '"The organization of unloaders may operate within the landlord port, handling the unloading of freight cars and barges."',
#    'weight': '1.0',
#    'rank': '11',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '236'},
#   {'id': '237',
#    'source': '"LANDLORD PORT"',
#    'target': '"DRAY CLERKS, WEIGHERS AND SAMPLERS"',
#    'description': '"The organization of clerks, weighers, and samplers likely works at the landlord port, dealing with cargo management and sampling."',
#    'weight': '1.0',
#    'rank': '11',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '237'},
#   {'id': '238',
#    'source': '"LANDLORD PORT"',
#    'target': '"SEAFARER’S INTERNATIONAL UNION"',
#    'description': 'Members of the Seafarer’s International Union work at Landlord Port, where they represent the interests of seafarers involved in various port activities. The union plays a crucial role in advocating for the rights and welfare of its members who are employed at the Landlord Port.',
#    'weight': '2.0',
#    'rank': '11',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '238'},
#   {'id': '239',
#    'source': '"LANDLORD PORT"',
#    'target': '"NATIONAL MARITIME UNION"',
#    'description': '"Members of the National Maritime Union may work at landlord ports, representing maritime workers."',
#    'weight': '1.0',
#    'rank': '11',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '239'},
#   {'id': '240',
#    'source': '"LANDLORD PORT"',
#    'target': '"MARINE ENGINEERS’ BENEFICIAL ASSOCIATION"',
#    'description': '"Marine engineers from this association may work at landlord ports, involved in the maintenance and operation of port machinery."',
#    'weight': '1.0',
#    'rank': '11',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '240'},
#   {'id': '260',
#    'source': '"LONGSHOREMEN"',
#    'target': '"MARITIME INDUSTRY"',
#    'description': '"Longshoremen work within the Maritime Industry, performing tasks related to the loading and unloading of ships."',
#    'weight': '1.0',
#    'rank': '11',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '260'},
#   {'id': '83',
#    'source': '"OIL TANKERS"',
#    'target': '"STATE PARTY"',
#    'description': '"Oil Tankers engaged in specific trades between ports or terminals within a State Party are subject to exemptions from regulations 18.6 to 18.8 of the Annex."',
#    'weight': '1.0',
#    'rank': '11',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '83'},
#   {'id': '303',
#    'source': '"STEAMSHIP COMPANY"',
#    'target': '"STEVEDORES"',
#    'description': '"Stevedores are hired by stevedoring firms to transfer cargo for steamship companies between ships and docks."',
#    'weight': '1.0',
#    'rank': '11',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '303'},
#   {'id': '105',
#    'source': '"MARPOL ANNEX I"',
#    'target': '"SHIPS"',
#    'description': '"Ships are required to comply with the accidental oil fuel outflow performance standard as per MARPOL Annex I regulations."',
#    'weight': '1.0',
#    'rank': '10',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '105'},
#   {'id': '116',
#    'source': '"BOARD OF COMMISSIONERS"',
#    'target': '"U.S. CUSTOMS"',
#    'description': '"The Board of Commissioners of a port authority may interact with U.S. Customs authorities regarding the storage and movement of goods."',
#    'weight': '1.0',
#    'rank': '9',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '116'},
#   {'id': '117',
#    'source': '"BOARD OF COMMISSIONERS"',
#    'target': '"BILL OF LADING"',
#    'description': '"The Board of Commissioners of a port authority oversees the operations that include the issuance and management of bills of lading."',
#    'weight': '1.0',
#    'rank': '9',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '117'},
#   {'id': '307',
#    'source': '"STEVEDORES"',
#    'target': '"TERMINAL"',
#    'description': '"Stevedores operate at terminals to transfer cargo between ships and docks."',
#    'weight': '1.0',
#    'rank': '9',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '307'},
#   {'id': '279',
#    'source': '"STEAMSHIP AGENT"',
#    'target': '"STEVEDORES"',
#    'description': '"Steamship Agents may coordinate with Stevedores for the loading and unloading of cargo from the ships."',
#    'weight': '1.0',
#    'rank': '9',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '279'},
#   {'id': '118',
#    'source': '"BOARD OF COMMISSIONERS"',
#    'target': '"BOLLARD"',
#    'description': '"The Board of Commissioners governs the port authority, which includes oversight of wharf equipment like bollards."',
#    'weight': '1.0',
#    'rank': '8',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '118'},
#   {'id': '119',
#    'source': '"BOARD OF COMMISSIONERS"',
#    'target': '"BONDED WAREHOUSE"',
#    'description': '"The Board of Commissioners oversees port authority operations, which may include the management of bonded warehouses."',
#    'weight': '1.0',
#    'rank': '8',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '119'},
#   {'id': '327',
#    'source': '"THE PORT OF NEW ORLEANS"',
#    'target': '"AAPA"',
#    'description': '"The Port of New Orleans is likely a member or associated with the American Association of Port Authorities."',
#    'weight': '1.0',
#    'rank': '8',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '327'},
#   {'id': '120',
#    'source': '"BOARD OF COMMISSIONERS"',
#    'target': '"BUOYS"',
#    'description': '"The Board of Commissioners is responsible for the safety and management of the port, which includes the placement and maintenance of buoys."',
#    'weight': '1.0',
#    'rank': '7',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '120'},
#   {'id': '258',
#    'source': '"LONGSHOREMEN"',
#    'target': '"MANIFEST"',
#    'description': '"Longshoremen may use the manifest to determine the cargo they need to load or unload from a ship."',
#    'weight': '1.0',
#    'rank': '7',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '258'},
#   {'id': '259',
#    'source': '"LONGSHOREMEN"',
#    'target': '"MARITIME"',
#    'description': '"Longshoremen work within the maritime industry, handling cargo at docks."',
#    'weight': '1.0',
#    'rank': '7',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '259'},
#   {'id': '306',
#    'source': '"STEAMSHIP LINE"',
#    'target': '"STEVEDORES"',
#    'description': '"Stevedores provide the labor and equipment necessary for the operation of Steamship Lines at docks."',
#    'weight': '1.0',
#    'rank': '7',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '306'},
#   {'id': '329',
#    'source': '"GEORGIA PORTS AUTHORITY"',
#    'target': '"AAPA"',
#    'description': '"Georgia Ports Authority is likely a member or associated with the American Association of Port Authorities."',
#    'weight': '1.0',
#    'rank': '7',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '329'},
#   {'id': '332',
#    'source': '"PORT OF HALIFAX"',
#    'target': '"AAPA"',
#    'description': '"Port of Halifax is likely a member or associated with the American Association of Port Authorities."',
#    'weight': '1.0',
#    'rank': '7',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '332'},
#   {'id': '308',
#    'source': '"STEVEDORES"',
#    'target': '"STRADDLE CARRIER"',
#    'description': '"Straddle carriers are used by stevedores to move containers within a terminal and assist in loading and unloading cargo."',
#    'weight': '1.0',
#    'rank': '6',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '308'},
#   {'id': '257',
#    'source': '"LAUNCH SERVICE COMPANIES"',
#    'target': '"LONGSHOREMEN"',
#    'description': 'Longshoremen often engage with Launch Service Companies during their work at ports. These interactions typically occur when longshoremen are tasked with loading or unloading cargo to and from ships that are at anchor. To facilitate this process, longshoremen may utilize the services provided by Launch Service Companies to reach these ships. This collaboration ensures that the cargo handling operations are carried out efficiently and effectively.',
#    'weight': '2.0',
#    'rank': '6',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '257'},
#   {'id': '90',
#    'source': '"THE ADMINISTRATION"',
#    'target': '"SURVEYS"',
#    'description': '"The Administration carries out surveys to enforce the provisions of the Annex and ensure ships\' compliance."',
#    'weight': '1.0',
#    'rank': '5',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '90'},
#   {'id': '139',
#    'source': '"CHANNELS OF DISTRIBUTION"',
#    'target': '"COMMON CARRIER"',
#    'description': '"Common carriers are part of the channels of distribution, as they transport goods nationwide."',
#    'weight': '1.0',
#    'rank': '5',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '139'},
#   {'id': '297',
#    'source': '"RO/RO SHIP"',
#    'target': '"VEHICLES"',
#    'description': '"Ro/Ro Ships are specifically designed to carry vehicles, which can drive on and off the ship."',
#    'weight': '1.0',
#    'rank': '5',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '297'},
#   {'id': '87',
#    'source': '"STATE PARTY"',
#    'target': '"PORT STATES"',
#    'description': '"The State Party to the present Convention must have an agreement with the Port States concerning the use of oil tankers for specific trades."',
#    'weight': '1.0',
#    'rank': '4',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '87'},
#   {'id': '145',
#    'source': '"COMMON CARRIER"',
#    'target': '"CONFERENCE RATE"',
#    'description': '"Common carriers may be subject to conference rates applicable to water transportation."',
#    'weight': '1.0',
#    'rank': '3',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '145'},
#   {'id': '289',
#    'source': '"PORT-OF-CALL"',
#    'target': '"CRUISE SHIP"',
#    'description': '"Port-of-Call is a stop for cruise ships along their itinerary."',
#    'weight': '1.0',
#    'rank': '3',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '289'},
#   {'id': '290',
#    'source': '"PROJECT CARGO"',
#    'target': '"SPECIAL PROJECT OVERSEAS"',
#    'description': '"Project Cargo is used for assembling a special project overseas."',
#    'weight': '1.0',
#    'rank': '3',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '290'}],
#  'claims': [],
#  'sources': [{'id': '9',
#    'text': ' concerning the use of an oil tanker for a specific trade.\n  .3 The adequacy of the reception facilities is approved by the Governments of the States Parties to the present Convention.\n  .4 The International Oil Pollution Prevention Certificate is endorsed to the effect that the oil tanker is solely engaged in such specific trade.\n\n#### Regulation 3: Exemptions and waivers\n1. Any ship whose constructional features render the application of any of the provisions of chapters 3 and 4 of this Annex or section 1.2 of part II-A of the Polar Code unreasonable or impracticable may be exempted by the Administration from such provisions.\n2. Particulars of any such exemption shall be indicated in the Certificate referred to in regulation 7 of this Annex.\n3. The Administration which allows any such exemption shall communicate to the Organization particulars of same and the reasons therefore.\n4. The Administration may waive the requirements of regulations 29, 31 and 32 of this Annex, for any oil tanker which engages exclusively on voyages both of 72 hours or less in duration and within 50 nautical miles from the nearest land.\n5. The Administration may waive the requirements of regulations 31 and 32 of this Annex for oil tankers other than those referred to in paragraph 4 of this regulation in cases where:\n.1 The tanker is an oil tanker delivered on or before 1 June 1982, solely engaged in specific trades.\n.2 The tanker is engaged exclusively in',
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '7fef1658b482777f6501772cea0b4647'},
#   {'id': '77',
#    'text': ' working conditions. The maritime unions within ports can include locals of the larger union, such as the General Longshore Workers; Clerks and Checkers; Sack-sewers, Sweepers, Water boys and Coopers; Dock Loaders and Unloaders of Freight Cars and Barges; Dray Clerks, Weighers and Samplers; plus the Seafarer’s International Union; the National Maritime Union; the Marine Engineers’ Beneficial Association and the Teamsters. Some laborers don’t belong to a union.\nlandlord port:\nAt a landlord port, the port authority builds the wharves, which it then rents or leases to a terminal operator (usually a stevedoring company). The operator invests in cargo-handling equipment (forklifts, cranes, etc), hires longshore laborers to operate such lift machinery and negotiates contracts with ocean carriers (steamship services) to handle the unloading and loading of ship cargoes. (See also\n:\noperating port\n.)\nLASH:\nThese 900-foot-long ships carry small barges inside the vessel. LASH stands for Lighter Aboard Ship. Just as cargo is transported by barge from the shallower parts of the Mississippi River to the Port of New Orleans for export aboard ocean-going ships, LASH barges are lifted into these unusual ships. Overseas, the ship can discharge clusters of barges in the open waters. Then several towboats will assemble the barges into to',
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '08831bbf674233a2a35c65aff497bcce'},
#   {'id': '83',
#    'text': ' whose occupation is to steep ships along a coast or into and out of a harbor. Local pilots board the ship to advise the captain and navigator of local navigation conditions (difficult currents; hidden wrecks, etc.).\nport:\nThis term is used both for the harbor area where ships are docked and for the agency (port authority), which administers use of public wharves and port properties.\nport-of-call\n: Port at which cruise ship makes a stop along its itinerary. Calls may range from five to 24 hours. Sometimes referred to as "transit port" and "destination port." (See also:\nhome port\n)\nproject cargo:\nThe materials and equipment to assemble a special project overseas, such as a factory or highway.\nquay\n: A wharf, which parallels the waterline.\nrailhead:\nEnd of the railroad line or point in the area of operations at which cargo is loaded and unloaded.\nrailyard:\nA rail terminal at which occur traditional railroad activities for sorting and redistribution of railcars and cargo.\nreefer:\nA container with refrigeration for transporting frozen foods (meat, ice cream, fruit, etc.)\nrefrigeration or reefer units:\nThe protective cooling of perishable freight by ice, liquid nitrogen, or mechanical devices\nro/ro:\nShort for roll on/roll/off . A ro/ro ship is designed with ramps that can be lowered to the dock so cars, buses, trucks or other vehicles can drive into',
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': 'cd60764ffb88b2bd29f71f26056a115c'},
#   {'id': '13',
#    'text': 'nage and above shall be subject to the surveys specified below:\n.1 An initial survey before the ship is put in service or before the Certificate required under regulation 7 of this Annex is issued for the first time.\n.2 A renewal survey at intervals specified by the Administration, but not exceeding 5 years.\n.3 An intermediate survey within 3 months before or after the second anniversary date or within 3 months before or after the third anniversary date of the Certificate.\n.4 An annual survey within 3 months before or after each anniversary date of the Certificate.\n.5 An additional survey either general or partial, according to the circumstances, after a repair resulting from investigations prescribed in paragraph 4.3 of this regulation.\nThe Administration shall establish appropriate measures for ships which are not subject to the provisions of paragraph 1 of this regulation in order to ensure that the applicable provisions of this Annex are complied with.\n3.1 Surveys of ships as regards the enforcement of the provisions of this Annex shall be carried out by officers of the Administration.\n3.2 An Administration nominating surveyors or recognizing organizations to conduct surveys shall empower any nominated surveyor or recognized organization to:\n.1 Require repairs to a ship.\n.2 Carry out surveys, if requested by the appropriate authorities of a port State.\n3.3 When a nominated surveyor or recognized organization determines that the condition of the ship or its equipment does not correspond substantially with the particulars of the Certificate, such surveyor or organization shall immediately ensure',
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '102b42dc9eff6eede9270bce0706e178'},
#   {'id': '51',
#    'text': ' term is used both for the harbor area where ships are docked and for the agency (port authority), which administers use of public wharves and port properties.\nport-of-call\n: Port at which cruise ship makes a stop along its itinerary. Calls may range from five to 24 hours. Sometimes referred to as "transit port" and "destination port." (See also:\nhome port\n)\nproject cargo:\nThe materials and equipment to assemble a special project overseas, such as a factory or highway.\nquay\n: A wharf, which parallels the waterline.\nrailhead:\nEnd of the railroad line or point in the area of operations at which cargo is loaded and unloaded.\nrailyard:\nA rail terminal at which occur traditional railroad activities for sorting and redistribution of railcars and cargo.\nreefer:\nA container with refrigeration for transporting frozen foods (meat, ice cream, fruit, etc.)\nrefrigeration or reefer units:\nThe protective cooling of perishable freight by ice, liquid nitrogen, or mechanical devices\nro/ro:\nShort for roll on/roll/off . A ro/ro ship is designed with ramps that can be lowered to the dock so cars, buses, trucks or other vehicles can drive into the belly of the ship, rather than be lifted aboard. A ro/ro ship, like a container ship, has a quick turnaround time of about 12 hours.\nRubber-Tired Gantry (RTG):\nTraveling crane',
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '788acc5be4c8c0e850edbede80008ead'},
#   {'id': '62',
#    'text': ' contract between a shipper and carrier listing the terms for moving freight between specified points.\nBoard of Commissioners:\nThe members of the governing board of a port authority are called commissioners. Members of a Board of Commissioners can be elected or appointed and usually serve for several years.\nbollard:\nA line-securing device on a wharf around which mooring and berthing lines are fastened.\nbonded warehouse:\nA building designated by U.S. Customs authorities for storage of goods without payment of duties to Customs until goods are removed.\nBox:\nSlang term for a container.\nbreakbulk cargo:\nNon-containerized general cargo stored in boxes, bales, pallets or other units to be loaded onto or discharged from ships or other forms of transportation. (See also:\nbulk\nand\ncontainer\n.) Examples include iron, steel, machinery, linerboard and woodpulp.\nbulk cargo:\nLoose cargo (dry or liquid) that is loaded (shoveled, scooped, forked, mechanically conveyed or pumped) in volume directly into a ship’s hold; e.g., grain, coal and oil.\nbulkhead\n: A structure used to protect against shifting cargo and/or to separate the load.\nBuoys:\nFloats that warn of hazards such as rocks or shallow ground, to help ships maneuver through unfamiliar harbors.\ncabotage:\nShipment of cargo between a nation’s ports is also called coastwise trade. The U.S. and some other countries require such',
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '290ef1352eee4727f6edc94a10f7676c'},
#   {'id': '61',
#    'text': ' has already traveled; a marine transportation carrier’s return movement of cargo, usually opposite from the direction of its primary cargo distribution.\nbarge:\nA large, flat-bottomed boat used to carry cargo from a port to shallow-draft waterways. Barges have no locomotion and are pushed by towboats. A single, standard barge can hold 1,500 tons of cargo or as much as either 15 railroad cars or 60 trucks can carry. A barge is 200 feet long, 35 feet wide and has a draft of 9 feet. Barges carry dry bulk (grain, coal, lumber, gravel, etc.) and liquid bulk (petroleum, vegetable oils, molasses, etc.).\nberth:\n(verb) To bring a ship to a berth. (noun) The wharf space at which a ship docks. A wharf may have two or three berths, depending on the length of incoming ships.\nbill of lading:\nA contract between a shipper and carrier listing the terms for moving freight between specified points.\nBoard of Commissioners:\nThe members of the governing board of a port authority are called commissioners. Members of a Board of Commissioners can be elected or appointed and usually serve for several years.\nbollard:\nA line-securing device on a wharf around which mooring and berthing lines are fastened.\nbonded warehouse:\nA building designated by U.S. Customs authorities for storage of goods without payment of duties',
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '0facc2d00bfe354e735f4bc66311731e'},
#   {'id': '29',
#    'text': 'ways. Barges have no locomotion and are pushed by towboats. A single, standard barge can hold 1,500 tons of cargo or as much as either 15 railroad cars or 60 trucks can carry. A barge is 200 feet long, 35 feet wide and has a draft of 9 feet. Barges carry dry bulk (grain, coal, lumber, gravel, etc.) and liquid bulk (petroleum, vegetable oils, molasses, etc.).\nberth:\n(verb) To bring a ship to a berth. (noun) The wharf space at which a ship docks. A wharf may have two or three berths, depending on the length of incoming ships.\nbill of lading:\nA contract between a shipper and carrier listing the terms for moving freight between specified points.\nBoard of Commissioners:\nThe members of the governing board of a port authority are called commissioners. Members of a Board of Commissioners can be elected or appointed and usually serve for several years.\nbollard:\nA line-securing device on a wharf around which mooring and berthing lines are fastened.\nbonded warehouse:\nA building designated by U.S. Customs authorities for storage of goods without payment of duties to Customs until goods are removed.\nBox:\nSlang term for a container.\nbreakbulk cargo:\nNon-containerized general cargo stored in boxes, bales, pallets or other units to be loaded onto or discharged from ships or other',
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': 'e0135fec749f19b9c3edb8aaa8f6e4b8'},
#   {'id': '45',
#    'text': ' and Unloaders of Freight Cars and Barges; Dray Clerks, Weighers and Samplers; plus the Seafarer’s International Union; the National Maritime Union; the Marine Engineers’ Beneficial Association and the Teamsters. Some laborers don’t belong to a union.\nlandlord port:\nAt a landlord port, the port authority builds the wharves, which it then rents or leases to a terminal operator (usually a stevedoring company). The operator invests in cargo-handling equipment (forklifts, cranes, etc), hires longshore laborers to operate such lift machinery and negotiates contracts with ocean carriers (steamship services) to handle the unloading and loading of ship cargoes. (See also\n:\noperating port\n.)\nLASH:\nThese 900-foot-long ships carry small barges inside the vessel. LASH stands for Lighter Aboard Ship. Just as cargo is transported by barge from the shallower parts of the Mississippi River to the Port of New Orleans for export aboard ocean-going ships, LASH barges are lifted into these unusual ships. Overseas, the ship can discharge clusters of barges in the open waters. Then several towboats will assemble the barges into tows bound for various ports and inland waterways, without the ship having to spend time traveling to each port.\nlaunch service:\nCompanies that offer "water-taxi" service to ships at anchor.\nLCL:\nThe acronym for "less',
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '61fdd9ff076a38fb59cc3e1021af4e9e'},
#   {'id': '8',
#    'text': ' The requirements of regulations 29, 31 and 32 of this Annex shall not apply to oil tankers carrying asphalt or other products which through their physical properties inhibit effective product/water separation and monitoring.\n5. Regulations 18.6 to 18.8 of this Annex shall not apply to an oil tanker delivered on or before 1 June 1982, solely engaged in specific trades between ports or terminals within a State Party to the present Convention.\n6. The provisions of paragraph 5 of this regulation shall only apply when the ports or terminals where cargo is loaded on such voyages are provided with reception facilities adequate for the reception and treatment of all the ballast and tank washing water from oil tankers using them and all the following conditions are complied with:\n  .1 All ballast water, including clean ballast water, and tank washing residues are retained on board and transferred to the reception facilities.\n  .2 Agreement has been reached between the Administration and the Governments of the Port States concerning the use of an oil tanker for a specific trade.\n  .3 The adequacy of the reception facilities is approved by the Governments of the States Parties to the present Convention.\n  .4 The International Oil Pollution Prevention Certificate is endorsed to the effect that the oil tanker is solely engaged in such specific trade.\n\n#### Regulation 3: Exemptions and waivers\n1. Any ship whose constructional features render the application of any of the provisions of chapters 3 and 4 of this Annex or',
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '7af0b635ad9b05e4bd87e86119774e17'},
#   {'id': '65',
#    'text': " city and parish government jobs are protected under civil service systems which are designed to provide a degree of security to employees and to deter nepotism, political patronage and arbitrary treatment of workers.\nclerks:\nWhen cargo is unloaded from a ship, a clerk checks the actual count of the goods (number of boxes, drums, bundles, pipes, etc.) versus the amount listed on the ship’s manifest. He will note shortages, overages or damage. This is used to make claims if needed.\ncommon carrier:\nTrucking, railroad or barge lines that are licensed to transport goods or people nationwide are called common carriers.\nConference rate:\nRates arrived at by conference of carriers applicable to water transportation.\nconsignment:\nA shipment of goods. The buyer of this shipment is called the\nconsignee;\nthe seller of the goods is called the\nconsignor.\nConsolidated Freight Station or Container Freight Station (CFS)\n- Location on terminal grounds where stuffing and stripping of containers is conducted.\nconsolidator:\nThe person or firm that consolidates (combines) cargo from a number of shippers into a container that will deliver the goods to several buyers.\ncontainer:\nA box made of aluminum, steel or fiberglass used to transport cargo by ship, rail, truck or barge. Common dimensions are 20' x 8’ x 8' (called a TEU or twenty-foot equivalent unit) or 40' x 8' x 8', called an",
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '84af951043bb33da9e6ddd0f58de42ac'},
#   {'id': '32',
#    'text': 'chandlers:\nLike a hotel at sea, a ship needs many supplies to operate and serve its crew-- groceries; paper products; engine parts; electronics; hardware; etc. A chandler sells these supplies to the ship’s agent. Originally, chandlers (candle makers) provided illumination to ships. Over time they expanded the variety of products they could provide to ships.\nchannels of distribution:\nThe routes by which products are transported from origin to destination. This includes the physical routes, as well as the different companies involved in ultimately delivering the goods to buyers.\ncheckers:\nSee\nclerks\n.\nchock:\nA piece of wood or other material put next to cargo to prevent it from shifting.\ncivil service:\nSome U.S., state, city and parish government jobs are protected under civil service systems which are designed to provide a degree of security to employees and to deter nepotism, political patronage and arbitrary treatment of workers.\nclerks:\nWhen cargo is unloaded from a ship, a clerk checks the actual count of the goods (number of boxes, drums, bundles, pipes, etc.) versus the amount listed on the ship’s manifest. He will note shortages, overages or damage. This is used to make claims if needed.\ncommon carrier:\nTrucking, railroad or barge lines that are licensed to transport goods or people nationwide are called common carriers.\nConference rate:\nRates arrived at by conference of carriers applicable to water transportation.\nconsignment:\nA shipment of',
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': 'd11e12558eb8792a7c8b20087c67b07c'},
#   {'id': '33',
#    'text': ' a ship, a clerk checks the actual count of the goods (number of boxes, drums, bundles, pipes, etc.) versus the amount listed on the ship’s manifest. He will note shortages, overages or damage. This is used to make claims if needed.\ncommon carrier:\nTrucking, railroad or barge lines that are licensed to transport goods or people nationwide are called common carriers.\nConference rate:\nRates arrived at by conference of carriers applicable to water transportation.\nconsignment:\nA shipment of goods. The buyer of this shipment is called the\nconsignee;\nthe seller of the goods is called the\nconsignor.\nConsolidated Freight Station or Container Freight Station (CFS)\n- Location on terminal grounds where stuffing and stripping of containers is conducted.\nconsolidator:\nThe person or firm that consolidates (combines) cargo from a number of shippers into a container that will deliver the goods to several buyers.\ncontainer:\nA box made of aluminum, steel or fiberglass used to transport cargo by ship, rail, truck or barge. Common dimensions are 20\' x 8’ x 8\' (called a TEU or twenty-foot equivalent unit) or 40\' x 8\' x 8\', called an FEU. Variations are collapsible containers, tank containers (for liquids) and "rag tops" (open-topped containers covered by a tarpaulin for cargo that sticks above the top of a closed box). In the',
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '754b13d4bb946fc01fa43ff8e7cbd773'},
#   {'id': '46',
#    'text': ' Mississippi River to the Port of New Orleans for export aboard ocean-going ships, LASH barges are lifted into these unusual ships. Overseas, the ship can discharge clusters of barges in the open waters. Then several towboats will assemble the barges into tows bound for various ports and inland waterways, without the ship having to spend time traveling to each port.\nlaunch service:\nCompanies that offer "water-taxi" service to ships at anchor.\nLCL:\nThe acronym for "less than container load." It refers to a partial container load that is usually consolidated with other goods to fill a container.\nLength Overall (LOA)\n: Linear measurement of a vessel from bow to stern.\nLift On-Lift Off (LO/LO):\nCargo handling technique involving transfer of commodities to and from the ship using shoreside cranes or ship\'s gear.\nLTL:\nMeans a shipment that is "less than truckload". Cargoes from different sources are usually consolidated to save costs.\nlong ton\n: A long ton equals 2240 pounds.\nlongshoremen:\nDock workers who load and unload ships, or perform administrative tasks associated with the loading or unloading of cargo. They may or may not be members of labor unions. Longshore gangs are hired by stevedoring firms to work the ships. Longshoremen are also called stevedores.\nmanifest:\nThe ship captain’s list of individual goods that make up the ship’s cargo.\nmarine surveyor:\nPerson who ins',
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '3aaa274980c4535abe058ce0f18b5270'},
#   {'id': '47',
#    'text': 'long ton\n: A long ton equals 2240 pounds.\nlongshoremen:\nDock workers who load and unload ships, or perform administrative tasks associated with the loading or unloading of cargo. They may or may not be members of labor unions. Longshore gangs are hired by stevedoring firms to work the ships. Longshoremen are also called stevedores.\nmanifest:\nThe ship captain’s list of individual goods that make up the ship’s cargo.\nmarine surveyor:\nPerson who inspects a ship hull or its cargo for damage or quality.\nmaster:\nThe officer in charge of the ship. "Captain" is a courtesy title often given to a master.\nmaritime:\n(adjective) Located on or near the sea. Commerce or navigation by sea. The maritime industry includes people working for transportation (ship, rail, truck and towboat/barge) companies, freight forwarders and customs brokers; stevedoring companies; labor unions; chandlers; warehouses; ship building and repair firms; importers/exporters; pilot associations, etc.\nmarshaling yard:\nThis is a container parking lot, or any open area where containers are stored in a precise order according to the ship loading plan. Containers terminals may use a grounded or wheeled layout. If the cargo box is placed directly on the ground, it is called a grounded operation. If the box is on a chassis/trailer, it is a wheeled operation.\nmean low water (MLW)\n: Lowest average level',
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '9b42d50c11e675e8491634850a9c72b5'},
#   {'id': '79',
#    'text': ' technique involving transfer of commodities to and from the ship using shoreside cranes or ship\'s gear.\nLTL:\nMeans a shipment that is "less than truckload". Cargoes from different sources are usually consolidated to save costs.\nlong ton\n: A long ton equals 2240 pounds.\nlongshoremen:\nDock workers who load and unload ships, or perform administrative tasks associated with the loading or unloading of cargo. They may or may not be members of labor unions. Longshore gangs are hired by stevedoring firms to work the ships. Longshoremen are also called stevedores.\nmanifest:\nThe ship captain’s list of individual goods that make up the ship’s cargo.\nmarine surveyor:\nPerson who inspects a ship hull or its cargo for damage or quality.\nmaster:\nThe officer in charge of the ship. "Captain" is a courtesy title often given to a master.\nmaritime:\n(adjective) Located on or near the sea. Commerce or navigation by sea. The maritime industry includes people working for transportation (ship, rail, truck and towboat/barge) companies, freight forwarders and customs brokers; stevedoring companies; labor unions; chandlers; warehouses; ship building and repair firms; importers/exporters; pilot associations, etc.\nmarshaling yard:\nThis is a container parking lot, or any open area where containers are stored in a precise order according to the ship loading plan. Containers terminals may use a grounded or wheeled layout',
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '294a59a24678a237204168c44226756d'},
#   {'id': '78',
#    'text': 'operating port\n.)\nLASH:\nThese 900-foot-long ships carry small barges inside the vessel. LASH stands for Lighter Aboard Ship. Just as cargo is transported by barge from the shallower parts of the Mississippi River to the Port of New Orleans for export aboard ocean-going ships, LASH barges are lifted into these unusual ships. Overseas, the ship can discharge clusters of barges in the open waters. Then several towboats will assemble the barges into tows bound for various ports and inland waterways, without the ship having to spend time traveling to each port.\nlaunch service:\nCompanies that offer "water-taxi" service to ships at anchor.\nLCL:\nThe acronym for "less than container load." It refers to a partial container load that is usually consolidated with other goods to fill a container.\nLength Overall (LOA)\n: Linear measurement of a vessel from bow to stern.\nLift On-Lift Off (LO/LO):\nCargo handling technique involving transfer of commodities to and from the ship using shoreside cranes or ship\'s gear.\nLTL:\nMeans a shipment that is "less than truckload". Cargoes from different sources are usually consolidated to save costs.\nlong ton\n: A long ton equals 2240 pounds.\nlongshoremen:\nDock workers who load and unload ships, or perform administrative tasks associated with the loading or unloading of cargo. They may or may not be members of labor unions. Longshore gangs',
#    'index_name': 'c51a36fa8fa8941ce5a85b71dba3e2cc',
#    'index_id': '4b5dc890a6f7b0f4d1a1263ac3fbef40'}]}
