# %% [markdown]
# # GraphRAG API Demo
#
# This notebook is written as an advanced tutorial/demonstration on how to use the GraphRAG solution accelerator API. It builds on top of the concepts covered in the `1-Quickstart` notebook.

# %% [markdown]
# ## Existing APIs
#
# | HTTP Method | Endpoint         |
# |-------------|------------------|
# | GET         | /data
# | POST        | /data
# | DELETE      | /data/{storage_name}
# | GET         | /index
# | POST        | /index
# | DELETE      | /index/{index_name}
# | GET         | /index/status/{index_name}
# | POST        | /query/global
# | POST        | /query/local
# | GET         | /index/config/prompts
# | GET         | /source/report/{index_name}/{report_id}
# | GET         | /source/text/{index_name}/{text_unit_id}
# | GET         | /source/entity/{index_name}/{entity_id}
# | GET         | /source/claim/{index_name}/{claim_id}
# | GET         | /source/relationship/{index_name}/{relationship_id}
# | GET         | /graph/graphml/{index_name}
# | GET         | /graph/stats/{index_name}

# %% [markdown]
# ## Prerequisites
# Install 3rd party packages that are not part of the Python Standard Library

# %%
! pip install devtools pandas python-magic requests tqdm
# Out:
# Requirement already satisfied: devtools in /graphrag-accelerator/.venv/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: pandas in /graphrag-accelerator/.venv/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: python-magic in /graphrag-accelerator/.venv/lib/python3.10/site-packages (0.4.27)
# Requirement already satisfied: requests in /graphrag-accelerator/.venv/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: tqdm in /graphrag-accelerator/.venv/lib/python3.10/site-packages (4.66.4)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from devtools) (2.4.1)
# Requirement already satisfied: executing>=1.1.1 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from devtools) (2.0.1)
# Requirement already satisfied: pygments>=2.15.0 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from devtools) (2.18.0)
# Requirement already satisfied: numpy>=1.22.4 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from requests) (2024.7.4)
# Requirement already satisfied: six>=1.12.0 in /graphrag-accelerator/.venv/lib/python3.10/site-packages (from asttokens<3.0.0,>=2.0.0->devtools) (1.16.0)

# %%
import getpass
import json
import os
import sys
import time
from pathlib import Path
from zipfile import ZipFile

import magic
import pandas as pd
import requests
from devtools import pprint
from tqdm import tqdm

# %% [markdown]
# ## (REQUIRED) User Configuration
# Set the API subscription key, API base endpoint, and some file directory names that will be referenced later in this notebook.

# %% [markdown]
# #### API subscription key
#
# APIM supports multiple forms of authentication and access control (e.g. managed identity). For this notebook demonstration, we will use a **[subscription key](https://learn.microsoft.com/en-us/azure/api-management/api-management-subscriptions)**. To locate this key, visit the Azure Portal. The subscription key can be found under `<my_resource_group> --> <API Management service> --> <APIs> --> <Subscriptions> --> <Built-in all-access subscription> Primary Key`. For multiple API users, individual subscription keys can be generated.

# %%
# ocp_apim_subscription_key = getpass.getpass(
#     "Enter the subscription key to the GraphRag APIM:"
# )
ocp_apim_subscription_key = "a40d6ba55d0d4b50a517234e3fc5430b"
"""
"Ocp-Apim-Subscription-Key": 
    This is a custom HTTP header used by Azure API Management service (APIM) to 
    authenticate API requests. The value for this key should be set to the subscription 
    key provided by the Azure APIM instance in your GraphRAG resource group.
"""
headers = {"Ocp-Apim-Subscription-Key": ocp_apim_subscription_key}

# %% [markdown]
# #### Setup directories and API endpoint
#
# For demonstration purposes, please use the provided `get-wiki-articles.py` script to download a small set of wikipedia articles or provide your own data (graphrag requires txt files to be utf-8 encoded).

# %%
"""
These parameters must be defined by the notebook user:

- file_directory: a local directory of text files. The file structure should be flat,
                  with no nested directories. (i.e. file_directory/file1.txt, file_directory/file2.txt, etc.)
- storage_name:   a unique name to identify a blob storage container in Azure where files
                  from `file_directory` will be uploaded.
- index_name:     a unique name to identify a single graphrag knowledge graph index.
                  Note: Multiple indexes may be created from the same `storage_name` blob storage container.
- endpoint:       the base/endpoint URL for the GraphRAG API (this is the Gateway URL found in the APIM resource).
"""

file_directory = "files_kb"
storage_name = "https://stographrag.blob.core.windows.net/bwgma-kb"
index_name = "glossary-index"
endpoint = "https://apim-6bmgl4mbrqugu.azure-api.net"

# %%
assert (
    file_directory != "" and storage_name != "" and index_name != "" and endpoint != ""
)

# %% [markdown]
# ### Helper Functions
#
# For cleanliness, we've provided helper functions below that encapsulate http requests to make API interaction with each API endpoint more intuitive.

# %%
def upload_files(
    file_directory: str,
    storage_name: str,
    batch_size: int = 100,
    overwrite: bool = True,
    max_retries: int = 5,
) -> requests.Response | list[Path]:
    """
    Upload files to a blob storage container.

    Args:
    file_directory - a local directory of .txt files to upload. All files must be in utf-8 encoding.
    storage_name - a unique name for the Azure storage container.
    batch_size - the number of files to upload in a single batch.
    overwrite - whether or not to overwrite files if they already exist in the storage container.
    max_retries - the maximum number of times to retry uploading a batch of files if the API is busy.

    NOTE: Uploading files may sometimes fail if the blob container was recently deleted
    (i.e. a few seconds before. The solution "in practice" is to sleep a few seconds and try again.
    """
    url = endpoint + "/data"

    def upload_batch(
        files: list, storage_name: str, overwrite: bool, max_retries: int
    ) -> requests.Response:
        for _ in range(max_retries):
            response = requests.post(
                url=url,
                files=files,
                params={"storage_name": storage_name, "overwrite": overwrite},
                headers=headers,
            )
            # API may be busy, retry
            if response.status_code == 500:
                print("API busy. Sleeping and will try again.")
                time.sleep(10)
                continue
            return response
        return response

    batch_files = []
    accepted_file_types = ["text/plain"]
    filepaths = list(Path(file_directory).iterdir())
    for file in tqdm(filepaths):
        # validate that file is a file, has acceptable file type, has a .txt extension, and has utf-8 encoding
        if (
            not file.is_file()
            or file.suffix != ".txt"
            or magic.from_file(str(file), mime=True) not in accepted_file_types
        ):
            print(f"Skipping invalid file: {file}")
            continue
        # open and decode file as utf-8, ignore bad characters
        batch_files.append(
            ("files", open(file=file, mode="r", encoding="utf-8", errors="ignore"))
        )
        # upload batch of files
        if len(batch_files) == batch_size:
            response = upload_batch(batch_files, storage_name, overwrite, max_retries)
            # if response is not ok, return early
            if not response.ok:
                return response
            batch_files.clear()
    # upload remaining files
    if len(batch_files) > 0:
        response = upload_batch(batch_files, storage_name, overwrite, max_retries)
    return response


def delete_files(storage_name: str) -> requests.Response:
    """Delete a blob storage container."""
    url = endpoint + f"/data/{storage_name}"
    return requests.delete(url=url, headers=headers)


def list_files() -> requests.Response:
    """List all data storage containers."""
    url = endpoint + "/data"
    return requests.get(url=url, headers=headers)


def build_index(
    storage_name: str,
    index_name: str,
    entity_extraction_prompt_filepath: str = None,
    community_prompt_filepath: str = None,
    summarize_description_prompt_filepath: str = None,
) -> requests.Response:
    """Create a search index.
    This function kicks off a job that builds a knowledge graph (KG) index from files located in a blob storage container.
    """
    url = endpoint + "/index"
    prompt_files = dict()
    if entity_extraction_prompt_filepath:
        prompt_files["entity_extraction_prompt"] = open(
            entity_extraction_prompt_filepath, "r"
        )
    if community_prompt_filepath:
        prompt_files["community_report_prompt"] = open(community_prompt_filepath, "r")
    if summarize_description_prompt_filepath:
        prompt_files["summarize_descriptions_prompt"] = open(
            summarize_description_prompt_filepath, "r"
        )
    return requests.post(
        url,
        files=prompt_files if len(prompt_files) > 0 else None,
        params={"index_name": index_name, "storage_name": storage_name},
        headers=headers,
    )


def delete_index(index_name: str) -> requests.Response:
    """Delete a search index."""
    url = endpoint + f"/index/{index_name}"
    return requests.delete(url, headers=headers)


def list_indexes() -> list:
    """List all search indexes."""
    url = endpoint + "/index"
    response = requests.get(url, headers=headers)
    try:
        indexes = json.loads(response.text)
        return indexes["index_name"]
    except json.JSONDecodeError:
        print(response.text)
        return response


def index_status(index_name: str) -> requests.Response:
    url = endpoint + f"/index/status/{index_name}"
    return requests.get(url, headers=headers)


def global_search(index_name: str | list[str], query: str) -> requests.Response:
    """Run a global query over the knowledge graph(s) associated with one or more indexes"""
    url = endpoint + "/query/global"
    request = {"index_name": index_name, "query": query}
    return requests.post(url, json=request, headers=headers)


def global_search_streaming(
    index_name: str | list[str], query: str
) -> requests.Response:
    """Run a global query across one or more indexes and stream back the response"""
    url = endpoint + "/experimental/query/global/streaming"
    request = {"index_name": index_name, "query": query}
    context_list = []
    with requests.post(url, json=request, headers=headers, stream=True) as r:
        r.raise_for_status()
        for chunk in r.iter_lines(chunk_size=256 * 1024, decode_unicode=True):
            try:
                payload = json.loads(chunk)
                token = payload["token"]
                context = payload["context"]
                if token != "<EOM>":
                    print(token, end="")
                elif (token == "<EOM>") and not context:
                    print("\n")  # transition from output message to context
                else:
                    context_list.append(context)
            except json.JSONDecodeError:
                print(type(chunk), len(chunk), sys.getsizeof(chunk), chunk, end="\n")
    display(pd.DataFrame.from_dict(context_list).head(10))


def local_search(index_name: str | list[str], query: str) -> requests.Response:
    """Run a local query over the knowledge graph(s) associated with one or more indexes"""
    url = endpoint + "/query/local"
    request = {"index_name": index_name, "query": query}
    return requests.post(url, json=request, headers=headers)


def get_graph_stats(index_name: str) -> requests.Response:
    """Get basic statistics about the knowledge graph constructed by GraphRAG."""
    url = endpoint + f"/graph/stats/{index_name}"
    return requests.get(url, headers=headers)


def save_graphml_file(index_name: str, graphml_file_name: str) -> None:
    """Retrieve and save a graphml file that represents the knowledge graph.
    The file is downloaded in chunks and saved to the local file system.
    """
    url = endpoint + f"/graph/graphml/{index_name}"
    if Path(graphml_file_name).suffix != ".graphml":
        raise UserWarning(f"{graphml_file_name} must have a .graphml file extension")
    with requests.get(url, headers=headers, stream=True) as r:
        r.raise_for_status()
        with open(graphml_file_name, "wb") as f:
            for chunk in r.iter_content(chunk_size=1024):
                f.write(chunk)


def get_report(index_name: str, report_id: str) -> requests.Response:
    """Retrieve a report generated by GraphRAG for a specific index."""
    url = endpoint + f"/source/report/{index_name}/{report_id}"
    return requests.get(url, headers=headers)


def get_entity(index_name: str, entity_id: str) -> requests.Response:
    """Retrieve an entity generated by GraphRAG for a specific index."""
    url = endpoint + f"/source/entity/{index_name}/{entity_id}"
    return requests.get(url, headers=headers)


def get_relationship(index_name: str, relationship_id: str) -> requests.Response:
    """Retrieve a relationship generated by GraphRAG for a specific index."""
    url = endpoint + f"/source/relationship/{index_name}/{relationship_id}"
    return requests.get(url, headers=headers)


def get_claim(index_name: str, claim_id: str) -> requests.Response:
    """Retrieve a claim/covariate generated by GraphRAG for a specific index."""
    url = endpoint + f"/source/claim/{index_name}/{claim_id}"
    return requests.get(url, headers=headers)


def get_text_unit(index_name: str, text_unit_id: str) -> requests.Response:
    """Retrieve a text unit generated by GraphRAG for a specific index."""
    url = endpoint + f"/source/text/{index_name}/{text_unit_id}"
    return requests.get(url, headers=headers)


def parse_query_response(
    response: requests.Response, return_context_data: bool = False
) -> requests.Response | dict[list[dict]]:
    """
    Prints response['result'] value and optionally
    returns associated context data.
    """
    if response.ok:
        print(json.loads(response.text)["result"])
        if return_context_data:
            return json.loads(response.text)["context_data"]
        return response
    else:
        print(response.reason)
        print(response.content)
        return response


def generate_prompts(storage_name: str, zip_file_name: str, limit: int = 1) -> None:
    """Generate graphrag prompts using data provided in a specific storage container."""
    url = endpoint + "/index/config/prompts"
    params = {"storage_name": storage_name, "limit": limit}
    with requests.get(url, params=params, headers=headers, stream=True) as r:
        r.raise_for_status()
        with open(zip_file_name, "wb") as f:
            for chunk in r.iter_content():
                f.write(chunk)

# %% [markdown]
# ## Upload files
#
# Use the API to upload a collection of local files. The API will create a new storage blob container to host these files in. For a set of large files, consider reducing the batch upload size in order to not overwhelm the API endpoint and prevent out-of-memory problems.

# %%
response = upload_files(
    file_directory=file_directory,
    storage_name=storage_name,
    batch_size=100,
    overwrite=True,
)
if not response.ok:
    print(response.text)
else:
    print(response)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 64.92it/s]
# <Response [200]>

# %% [markdown]
# #### To list all existing data storage containers:

# %%
response = list_files()
print(response)
if response.ok:
    pprint(response.json())
else:
    pprint(response.text)
# Out:
# <Response [200]>
# {
#     'storage_name': [
#         'https://stographrag.blob.core.windows.net/bwgma-kb',
#         'graphrag-storage-container',
#     ],
# }

# %% [markdown]
# #### To remove files from the GraphRAG service:

# %%
# # uncomment this cell to delete data container
# response = delete_files(storage_name)
# print(response)
# pprint(response.text)

# %% [markdown]
# ## Auto-Template Generation (Optional)
#
# GraphRAG constructs a knowledge graph from data based on the ability to identify entities and the relationships between them. To improve the quality of the knowledge graph constructed by GraphRAG over private data, we provide a feature called "Automatic Templating". This capability takes user-provided data samples and generates custom-tailored prompts based on characteristics of that data. These custom prompts contain few-shot examples of entities and relationships, which can then be used to build a graphrag index.

# %%
generate_prompts(storage_name=storage_name, limit=1, zip_file_name="prompts.zip")
with ZipFile("prompts.zip", "r") as zip_ref:
    zip_ref.extractall()

# %% [markdown]
# After running the previous cell, a new local directory (`prompts`) will be created. Please look at the prompts (`prompts/entity_extraction.txt`, `prompts/community_report.txt`, and `prompts/summarize_descriptions.txt`) that were generated from the user-provided data. Users are encouraged to spend some time and inspect/modify these prompts, taking into account characteristics of their data and their own goals of what kind/type of knowledge they wish to extract and model with graphrag.

# %% [markdown]
# ## Build an Index
#
# After data files have been uploaded and (optionally) custom promps have been generated, it is time to construct a knowledge graph by building an index. If custom prompts are not provided (demonstrated in the `1-Quickstart` notebook), default built-in prompts are used that we find generally work well.

# %% [markdown]
# #### Start a new indexing job

# %%
# check if prompt files exist
entity_extraction_prompt_filepath = "prompts/entity_extraction.txt"
community_prompt_filepath = "prompts/community_report.txt"
summarize_description_prompt_filepath = "prompts/summarize_descriptions.txt"
entity_prompt = (
    entity_extraction_prompt_filepath
    if os.path.isfile(entity_extraction_prompt_filepath)
    else None
)
community_prompt = (
    community_prompt_filepath if os.path.isfile(community_prompt_filepath) else None
)
summarize_prompt = (
    summarize_description_prompt_filepath
    if os.path.isfile(summarize_description_prompt_filepath)
    else None
)

response = build_index(
    storage_name=storage_name,
    index_name=index_name,
    entity_extraction_prompt_filepath=entity_prompt,
    community_prompt_filepath=community_prompt,
    summarize_description_prompt_filepath=summarize_prompt,
)
if response.ok:
    pprint(response.json())
else:
    print(f"Failed to submit job.\nStatus: {response.text}")
# Out:
# {
#     'detail': 'an index with name glossary-index already exists and has not finished building.',
# }

# %% [markdown]
# Note: An indexing job may fail sometimes due to insufficient TPM quota of the Azure OpenAI model. In this situation, an indexing job can be restarted by re-running the cell above with the same parameters. `graphrag` caches previous indexing results as a cost-savings measure so that restarting indexing jobs will "pick up" where the last job stopped.

# %% [markdown]
# #### Check the status of an indexing job
#
# Please wait for your index to reach 100 percent completion before continuing on to the next section (running queries). You may rerun the next cell multiple times to monitor status. Note: the indexing speed of graphrag is directly correlated to the TPM quota of the Azure OpenAI model you are using.

# %%
response = index_status(index_name)
print(response)
if response.ok:
    pprint(response.json())
else:
    print(response.text)
# Out:
# <Response [200]>
# {
#     'status_code': 200,
#     'index_name': 'glossary-index',
#     'storage_name': 'https://stographrag.blob.core.windows.net/bwgma-kb',
#     'status': 'running',
#     'percent_complete': 18.75,
#     'progress': 'Workflow create_summarized_entities started.',
# }

# %% [markdown]
# #### List indexes
# To view a list of all indexes that exist in the GraphRAG service:

# %%
all_indexes = list_indexes()
pprint(all_indexes)
# Out:
# [
#     'glossary-index',
#     'alfa-laval-mbpx404-index',
# ]

# %% [markdown]
# #### Delete an indexing job
# If an index is no longer needed, remove it from the GraphRAG service.

# %%
# uncomment this cell to delete an index

# response = delete_index('gloss-index')
# print(response)
# pprint(response.json())

# %% [markdown]
# ## Query
#
# Once an indexing job is complete, the knowledge graph is ready to query. Two types of queries (global and local) are currently supported. We encourage you to try both and experience the difference in responses. Note that query response time is also correlated to the TPM quota of the Azure OpenAI model you are using.

# %% [markdown]
# #### Global Search
#
# Global search queries are resource-intensive, but give good responses to questions that require an understanding of the dataset as a whole.

# %%
# %%time
# pass in a single index name as a string or to query across multiple indexes, set index_name=[myindex1, myindex2]
global_response = global_search(
    index_name=index_name, query="Summarize the main topics of this data"
)
# print the result and save context data in a variable
global_response_data = parse_query_response(global_response, return_context_data=True)
global_response_data
# Out:
# Internal Server Error
# b'{"detail":"f5750306ce0f16003f963b539668748e not ready for querying."}'
# CPU times: user 3.97 ms, sys: 3.21 ms, total: 7.18 ms
# Wall time: 2.34 s
# <Response [500]>

# %% [markdown]
# An *experimental* API endpoint has been designed to support streaming back the graphrag response while executing a global query (useful in applications like a chatbot).

# %%
global_search_streaming(
    index_name=index_name, query="Summarize the main topics of this data"
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 global_search_streaming(
#       2     index_name=index_name, query="Summarize the main topics of this data"
#       3 )
#
# Cell In[70], line 150, in global_search_streaming(index_name, query)
#     148 context_list = []
#     149 with requests.post(url, json=request, headers=headers, stream=True) as r:
# --> 150     r.raise_for_status()
#     151     for chunk in r.iter_lines(chunk_size=256 * 1024, decode_unicode=True):
#     152         try:
#
# File /graphrag-accelerator/.venv/lib/python3.10/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 500 Server Error: Internal Server Error for url: https://apim-6bmgl4mbrqugu.azure-api.net/experimental/query/global/streaming

# %% [markdown]
# #### Local Search
#
# Local search queries are best suited for narrow-focused questions that require an understanding of specific entities mentioned in the documents (e.g. What are the healing properties of chamomile?)

# %%
# %%time
# pass in a single index name as a string or to query across multiple indexes, set index_name=[myindex1, myindex2]
local_response = local_search(
    index_name=index_name, query="Who are the primary actors in these communities?"
)
# print the result and save context data in a variable
local_response_data = parse_query_response(local_response, return_context_data=True)
local_response_data
# Out:
# # Overview of Primary Actors in Maritime Supply Chain Communities
#
# The maritime supply chain is a complex network involving various entities that collaborate to ensure the efficient flow of goods globally. Below is a summary of the primary actors within these communities:
#
# ## Marshaling Yards
# Marshaling yards are pivotal logistics facilities that organize and store containers according to ship loading plans. They employ both grounded and wheeled methods for container management, playing a critical role in minimizing delays and optimizing space utilization on ocean carriers [Data: Entities (312); Claims (218, 339, 341); Relationships (464, 456, 465, 459, 462)].
#
# ## Ocean Carriers
# Ocean carriers are modern diesel-fueled vessels that have evolved from older steamships. They are responsible for the overseas transport of various cargo types, including neo-bulk and consolidated freight from NVOCCs. Their efficiency and integration with on-dock rail services are vital for maintaining the flow of goods across borders [Data: Entities (322); Claims (254, 349); Relationships (483, 480, 477, 481, 470)].
#
# ## NVOCCs (Non-Vessel Owning Common Carriers)
# NVOCCs enable small shippers to access competitive shipping costs by consolidating freight and purchasing space on ships. They issue bills of lading and book space aboard ocean carriers, optimizing cargo space utilization and streamlining the shipping process [Data: Entities (320); Claims (346, 348); Relationships (475, 476, 469)].
#
# ## On-Dock Rail Services
# On-dock rail services provide a direct connection between rail cars and vessels, allowing for immediate loading and unloading of containers or breakbulk cargo. This minimizes additional handling or transportation, reducing potential delays and enhancing supply chain efficiency [Data: Entities (325); Relationships (481)].
#
# ## Maritime Industry
# The maritime industry encompasses a wide array of activities and organizations, including transportation companies, freight forwarders, customs brokers, stevedoring companies, labor unions, and pilot associations. This diverse network of operations is interconnected and essential for the smooth functioning of the global supply chain [Data: Entities (412); Claims (338, 340); Relationships (465, 462, 473, 479, 474)].
#
# ## Longshoremen
# Longshoremen, also known as stevedores, are dock workers who specialize in loading and unloading cargo from ships. They are often organized into unions and play a crucial role in the workforce, ensuring the efficient movement and management of goods at ports [Data: Entities (308); Relationships (455, 456, 454, 450, 452)].
#
# ## Maritime Unions
# Maritime unions represent the collective interests of workers in various maritime roles, negotiating working conditions and labor contracts with terminal operators and other entities within the ports [Data: Entities (410); Relationships (437, 429, 434, 539)].
#
# ## Pilot Associations
# Pilot associations are professional groups that represent maritime pilots who navigate ships through hazardous or congested waters, such as harbors or river mouths [Data: Entities (316); Relationships (470)].
#
# These actors are integral to the maritime supply chain, each contributing to the overall efficiency and reliability of global trade. Their roles and interactions are fundamental to the seamless integration of sea transport with land-based logistics networks.
# CPU times: user 5.54 ms, sys: 3.9 ms, total: 9.44 ms
# Wall time: 21.9 s
# {'reports': [{'id': '73',
#    'title': 'Intermodal Transportation Efficiency in the Maritime Supply Chain',
#    'content': "# Intermodal Transportation Efficiency in the Maritime Supply Chain\n\nThe community is centered around the intermodal transportation system within the maritime supply chain, involving entities such as marshaling yards, ocean carriers, NVOCCs, and on-dock rail services. These entities work in concert to optimize the flow of goods, from storage and organization to transportation and delivery, ensuring the efficiency of global trade.\n\n## Marshaling Yard as a pivotal logistics facility\n\nThe marshaling yard is a key logistics facility within the community, serving as a strategic point for the organization and storage of containers according to ship loading plans. The yard's operations, which include both grounded and wheeled methods, are essential for ensuring efficient loading processes onto ships, thereby facilitating smooth transitions in the intermodal transportation chain. The precise organization of containers in the marshaling yard is crucial for minimizing delays and optimizing the use of space on ocean carriers. [records: Entities (312), Claims (218, 339, 341), Relationships (464, 456, 465, 459, 462)]\n\n## Ocean Carrier's role in global trade\n\nOcean carriers, as modern diesel-fueled vessels, are central to the maritime industry and international supply chains. They have evolved from the older steamships and are responsible for the overseas transport of various types of cargo, including neo-bulk and consolidated freight from NVOCCs. The efficiency and reliability of ocean carriers are vital for maintaining the flow of goods across borders, and their integration with on-dock rail services further enhances the intermodal transportation system. [records: Entities (322), Claims (254, 349), Relationships (483, 480, 477, 481, 470)]\n\n## NVOCCs as facilitators for small shippers\n\nNVOCCs play a crucial role in the community by enabling small shippers to access competitive shipping costs. By consolidating freight and purchasing space on ships, NVOCCs optimize cargo space utilization and streamline the shipping process. Their operations are integral to the fluidity of the supply chain, as they issue bills of lading and book space aboard ocean carriers, ensuring that goods are transported efficiently and effectively. [records: Entities (320), Claims (346, 348), Relationships (475, 476, 469)]\n\n## On-Dock Rail's contribution to supply chain efficiency\n\nON-DOCK RAIL services provide a direct connection between rail cars and vessels, allowing for the immediate loading and unloading of containers or breakbulk cargo. This direct shipside rail service minimizes the need for additional handling or transportation, thereby reducing potential delays and enhancing the efficiency of the supply chain. The integration of ON-DOCK RAIL with ocean carriers exemplifies the effectiveness of intermodal transportation solutions. [records: Entities (325), Relationships (481)]\n\n## Maritime Industry's diverse operations\n\nThe maritime industry encompasses a wide array of activities and organizations, including transportation companies, freight forwarders, customs brokers, stevedoring companies, labor unions, and pilot associations. This diversity indicates a complex network of operations that are all interconnected and essential for the smooth functioning of the global supply chain. The industry's efficiency is dependent on the seamless integration of these various entities, highlighting the importance of intermodal transportation systems. [records: Entities (412), Claims (338, 340), Relationships (465, 462, 473, 479, 474)]",
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '73'}],
#  'entities': [{'id': '387',
#    'entity': 'SHIPPER',
#    'description': '',
#    'number of relationships': '2',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '387'},
#   {'id': '86',
#    'entity': 'GOVERNMENTS',
#    'description': 'Governments are the governing bodies of states or countries that approve the adequacy of reception facilities as per international conventions>',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '86'},
#   {'id': '269',
#    'entity': 'TUGS',
#    'description': '',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '269'},
#   {'id': '315',
#    'entity': 'IMPORTERS/EXPORTERS',
#    'description': 'Importers and exporters are businesses or individuals that bring goods into a country or send goods to other countries as part of international trade>',
#    'number of relationships': '2',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '315'},
#   {'id': '65',
#    'entity': 'PERSONS',
#    'description': 'Persons refer to human beings, in this context specifically mentioned as not being on board the ship>',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '65'},
#   {'id': '417',
#    'entity': 'VEHICLES',
#    'description': '',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '417'},
#   {'id': '311',
#    'entity': 'MARITIME',
#    'description': 'MARITIME refers to activities located on or near the sea, primarily involving commerce or navigation by sea. This term encompasses a broad spectrum of entities and sectors including transportation companies, freight forwarders, customs brokers, stevedoring companies, labor unions, chandlers, warehouses, shipbuilding and repair firms, importers/exporters, and pilot associations. These stakeholders are integral to the maritime industry, which is characterized by its diverse range of operations related to the sea and seafaring logistics.',
#    'number of relationships': '4',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '311'},
#   {'id': '296',
#    'entity': 'TEAMSTERS',
#    'description': 'The Teamsters is a labor union that represents a diverse membership of blue-collar and professional workers in both the public and private sectors>',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '296'},
#   {'id': '187',
#    'entity': 'BOARD OF COMMISSIONERS',
#    'description': 'The Board of Commissioners is the governing body of a port authority, comprised of individuals who may either be elected or appointed to their positions. These members serve terms that span several years, overseeing the operations and making strategic decisions for the port authority. Their role is crucial in ensuring the efficient management and operation of the port, which is a critical node in many supply chain networks.',
#    'number of relationships': '2',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '187'},
#   {'id': '203',
#    'entity': 'DOMESTIC SHIPS',
#    'description': '',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '203'},
#   {'id': '410',
#    'entity': 'MARITIME UNIONS',
#    'description': 'Maritime unions are organizations within ports that represent the collective interests of workers in various maritime roles, including General Longshore Workers, Clerks and Checkers, Sack-sewers, Sweepers, Water boys and Coopers, Dock Loaders and Unloaders of Freight Cars and Barges, Dray Clerks, Weighers and Samplers, as well as larger unions like the Seafarer’s International Union, the National Maritime Union, the Marine Engineers’ Beneficial Association, and the Teamsters',
#    'number of relationships': '2',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '410'},
#   {'id': '415',
#    'entity': 'LOCAL PILOTS',
#    'description': "Local pilots are maritime professionals whose occupation involves guiding ships along a coast or into and out of a harbor, providing advice to the ship's captain and navigator about local navigation conditions such as difficult currents and hidden wrecks",
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '415'},
#   {'id': '394',
#    'entity': "NATION'S PORTS",
#    'description': '',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '394'},
#   {'id': '412',
#    'entity': 'MARITIME INDUSTRY',
#    'description': 'The maritime industry encompasses a wide range of activities and organizations including transportation companies (ship, rail, truck, towboat/barge), freight forwarders, customs brokers, stevedoring companies, labor unions, chandlers, warehouses, ship building and repair firms, importers/exporters, pilot associations, etc.',
#    'number of relationships': '5',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '412'},
#   {'id': '316',
#    'entity': 'PILOT ASSOCIATIONS',
#    'description': 'Pilot associations are professional groups that represent maritime pilots who navigate ships through hazardous or congested waters, such as harbors or river mouths>',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '316'},
#   {'id': '308',
#    'entity': 'LONGSHOREMEN',
#    'description': 'Longshoremen, also known as stevedores, are dock workers who specialize in loading and unloading cargo from ships. Their responsibilities extend beyond the physical handling of goods to include administrative tasks associated with the cargo handling process. These workers may be organized into groups known as longshore gangs and are often hired by stevedoring firms. Additionally, longshoremen may be members of labor unions, which provide a collective bargaining platform and work to protect their rights and interests in the workplace. Their role is critical in the maritime industry, ensuring the efficient and safe transfer of goods between ship and shore.',
#    'number of relationships': '6',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '308'},
#   {'id': '215',
#    'entity': 'COMMON CARRIER',
#    'description': 'Common carriers are licensed transportation companies that operate nationwide, providing services such as trucking, railroad, or barge lines. These entities are authorized to transport both goods and people across the country. Their operations are essential for the movement of a wide range of commodities and for facilitating travel for individuals, playing a crucial role in the national logistics and supply chain network.',
#    'number of relationships': '3',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '215'},
#   {'id': '291',
#    'entity': 'UNLOADERS OF FREIGHT CARS AND BARGES',
#    'description': 'Unloaders of freight cars and barges are laborers responsible for the unloading of cargo from freight cars and barges>',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '291'},
#   {'id': '379',
#    'entity': 'TRACTOR',
#    'description': 'The tractor is the front part of a tractor-trailer, also known as a cab, which pulls the trailer and is responsible for the movement of the vehicle>',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '379'},
#   {'id': '117',
#    'entity': 'OWNER',
#    'description': 'The owner of a ship is the individual or entity that legally possesses the ship and is responsible for its management and operations>',
#    'number of relationships': '2',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '117'}],
#  'relationships': [{'id': '455',
#    'source': 'LONGSHOREMEN',
#    'target': 'MARITIME',
#    'description': 'Longshoremen are integral members of the maritime industry, specifically engaged in the transportation and cargo handling sectors. They play a crucial role in the workforce, ensuring the efficient movement and management of goods as they are loaded and unloaded from ships at ports. Their work is essential to the functioning of global trade and the supply chain, as they facilitate the transfer of cargo between sea transport and land-based logistics networks.',
#    'weight': '2.0',
#    'rank': '10',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '455'},
#   {'id': '456',
#    'source': 'LONGSHOREMEN',
#    'target': 'MARSHALING YARD',
#    'description': 'Longshoremen may work in marshaling yards organizing and handling containers',
#    'weight': '1.0',
#    'rank': '13',
#    'links': '4',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '456'},
#   {'id': '465',
#    'source': 'MARSHALING YARD',
#    'target': 'MARITIME INDUSTRY',
#    'description': 'Marshaling yards are a critical component of the maritime industry, serving as storage and organization points for containers before they are loaded onto ships',
#    'weight': '1.0',
#    'rank': '12',
#    'links': '4',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '465'},
#   {'id': '462',
#    'source': 'MARITIME',
#    'target': 'MARSHALING YARD',
#    'description': "Marshaling yards are a part of the maritime industry's infrastructure for organizing container storage",
#    'weight': '1.0',
#    'rank': '11',
#    'links': '4',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '462'},
#   {'id': '463',
#    'source': 'MARSHALING YARD',
#    'target': 'IMPORTERS/EXPORTERS',
#    'description': 'Importers and exporters use marshaling yards to store containers before they are loaded onto or after being unloaded from ships',
#    'weight': '1.0',
#    'rank': '9',
#    'links': '4',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '463'},
#   {'id': '437',
#    'source': 'LANDLORD PORT',
#    'target': 'MARITIME UNIONS',
#    'description': 'Maritime unions may represent the longshore laborers who are hired by terminal operators at landlord ports',
#    'weight': '1.0',
#    'rank': '16',
#    'links': '3',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '437'},
#   {'id': '429',
#    'source': 'LANDLORD PORT',
#    'target': 'UNLOADERS OF FREIGHT CARS AND BARGES',
#    'description': 'Unloaders of freight cars and barges may work at landlord ports, where they handle the unloading of ship cargoes',
#    'weight': '1.0',
#    'rank': '15',
#    'links': '3',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '429'},
#   {'id': '434',
#    'source': 'LANDLORD PORT',
#    'target': 'TEAMSTERS',
#    'description': 'The Teamsters may represent some of the laborers working at landlord ports',
#    'weight': '1.0',
#    'rank': '15',
#    'links': '3',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '434'},
#   {'id': '476',
#    'source': 'NVOCC',
#    'target': 'MARITIME INDUSTRY',
#    'description': 'NVOCCs operate within the maritime industry, facilitating the transportation of goods for small shippers by consolidating freight and booking space on ships',
#    'weight': '1.0',
#    'rank': '8',
#    'links': '2',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '476'},
#   {'id': '469',
#    'source': 'IMPORTERS/EXPORTERS',
#    'target': 'NVOCC',
#    'description': 'NVOCCs provide services to importers and exporters by consolidating freight and arranging for its shipment',
#    'weight': '1.0',
#    'rank': '5',
#    'links': '2',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '469'},
#   {'id': '274',
#    'source': 'CABOTAGE',
#    'target': 'DOMESTIC SHIPS',
#    'description': 'Cabotage laws often require the use of domestic ships for trade between national ports',
#    'weight': '1.0',
#    'rank': '5',
#    'links': '2',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '274'},
#   {'id': '276',
#    'source': 'CABOTAGE',
#    'target': "NATION'S PORTS",
#    'description': "Cabotage involves the shipment of cargo between a nation's ports",
#    'weight': '1.0',
#    'rank': '5',
#    'links': '2',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '276'},
#   {'id': '153',
#    'source': 'ADMINISTRATION',
#    'target': 'OWNER',
#    'description': 'The owner is responsible for reporting accidents or defects of the ship to the Administration',
#    'weight': '1.0',
#    'rank': '26',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '153'},
#   {'id': '86',
#    'source': 'SHIP',
#    'target': 'OWNER',
#    'description': 'The owner possesses the ship and is responsible for its management and operations',
#    'weight': '1.0',
#    'rank': '23',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '86'},
#   {'id': '288',
#    'source': 'CONTAINER',
#    'target': 'COMMON CARRIER',
#    'description': "Common carriers are responsible for the transportation of containers, which are filled with goods, utilizing various modes of transportation. This process involves the movement of cargo, encapsulated in these containers, to facilitate the distribution and delivery of products. The common carrier's role is pivotal in ensuring that these goods are transported efficiently and effectively through different channels, such as road, rail, sea, or air, depending on the requirements of the supply chain network.",
#    'weight': '2.0',
#    'rank': '18',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '288'},
#   {'id': '215',
#    'source': 'PORT',
#    'target': 'LOCAL PILOTS',
#    'description': 'Local pilots operate within ports, guiding ships into and out of the harbor',
#    'weight': '1.0',
#    'rank': '14',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '215'},
#   {'id': '454',
#    'source': 'LONGSHOREMEN',
#    'target': 'MANIFEST',
#    'description': 'Longshoremen utilize the manifest as a crucial document to ascertain the specific cargo or goods that need to be loaded or unloaded from a ship. This process is essential for the efficient and accurate handling of shipments at ports.',
#    'weight': '3.0',
#    'rank': '11',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '454'},
#   {'id': '124',
#    'source': 'PERSONS',
#    'target': 'SHIPS',
#    'description': 'The ship is described as not having persons on board, which is unusual as ships typically have crew',
#    'weight': '1.0',
#    'rank': '10',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '124'},
#   {'id': '470',
#    'source': 'PILOT ASSOCIATIONS',
#    'target': 'OCEAN CARRIER',
#    'description': 'Members of pilot associations navigate ocean carriers through difficult or congested waters',
#    'weight': '1.0',
#    'rank': '9',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '470'},
#   {'id': '323',
#    'source': 'CHANNELS OF DISTRIBUTION',
#    'target': 'COMMON CARRIER',
#    'description': 'Common carriers operate within the channels of distribution to transport goods nationwide',
#    'weight': '1.0',
#    'rank': '9',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '323'},
#   {'id': '450',
#    'source': 'LIFT ON-LIFT OFF (LO/LO)',
#    'target': 'LONGSHOREMEN',
#    'description': 'Longshoremen are integral to the lift on-lift off (LO/LO) cargo handling technique, which they employ to load and unload cargo from ships. This method involves the use of cranes or other equipment to lift cargo on and off the vessels, facilitating efficient handling of goods at ports and terminals. The expertise of longshoremen in the LO/LO technique is essential for the smooth operation of maritime logistics and supply chain networks.',
#    'weight': '2.0',
#    'rank': '9',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '450'},
#   {'id': '473',
#    'source': 'MOORING DOLPHIN',
#    'target': 'MARITIME INDUSTRY',
#    'description': 'Mooring dolphins are used within the maritime industry for the secure berthing of boats and barges',
#    'weight': '1.0',
#    'rank': '9',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '473'},
#   {'id': '479',
#    'source': 'NEO-BULK CARGO',
#    'target': 'MARITIME INDUSTRY',
#    'description': 'Neo-bulk cargo is a type of cargo that is transported by the maritime industry',
#    'weight': '1.0',
#    'rank': '9',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '479'},
#   {'id': '457',
#    'source': 'LONGSHOREMEN',
#    'target': 'COMMODITY TRANSFER',
#    'description': 'Longshoremen are the workforce involved in the commodity transfer process, loading and unloading the ships',
#    'weight': '1.0',
#    'rank': '8',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '457'},
#   {'id': '142',
#    'source': 'RECEPTION FACILITIES',
#    'target': 'GOVERNMENTS',
#    'description': 'The adequacy of reception facilities for oil tankers must be approved by governments',
#    'weight': '1.0',
#    'rank': '8',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '142'},
#   {'id': '196',
#    'source': 'MASTER',
#    'target': 'MARITIME',
#    'description': "The master, a crucial professional within the maritime industry, is responsible for overseeing ship operations. This role entails the operation of a vessel, ensuring that all activities are conducted efficiently and safely within the maritime sector. The master's duties are integral to the successful management and coordination of maritime logistics, highlighting their importance in the flow of goods and information across global supply chains.",
#    'weight': '2.0',
#    'rank': '8',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '196'},
#   {'id': '452',
#    'source': 'LTL',
#    'target': 'LONGSHOREMEN',
#    'description': 'Longshoremen are involved in the handling of Less Than Truckload (LTL) shipments, both during the loading or unloading processes at docks and throughout the consolidation process. Their role is critical in managing the movement of LTL cargoes, ensuring that these smaller shipments are efficiently combined or distributed as part of the broader logistics and supply chain operations.',
#    'weight': '2.0',
#    'rank': '8',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '452'},
#   {'id': '474',
#    'source': 'MOTOR SHIP (MS) OR MOTOR VESSEL (MV)',
#    'target': 'MARITIME INDUSTRY',
#    'description': 'Motor ships or motor vessels are operated by companies within the maritime industry for the transportation of goods and passengers',
#    'weight': '1.0',
#    'rank': '8',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '474'},
#   {'id': '460',
#    'source': 'MARINE SURVEYOR',
#    'target': 'MARITIME',
#    'description': 'Marine surveyors, functioning within the maritime industry, are professionals responsible for inspecting ships and cargo. Their role is crucial in ensuring the seaworthiness of vessels and the proper handling and safety of cargo being transported. By conducting thorough inspections, marine surveyors contribute significantly to the maintenance of standards and regulations that govern maritime operations.',
#    'weight': '2.0',
#    'rank': '7',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '460'},
#   {'id': '539',
#    'source': 'TERMINAL OPERATOR',
#    'target': 'MARITIME UNIONS',
#    'description': 'Maritime unions may engage with terminal operators to negotiate labor contracts and represent the interests of the longshore laborers they hire',
#    'weight': '1.0',
#    'rank': '7',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '539'},
#   {'id': '546',
#    'source': 'TRACTOR-TRAILER',
#    'target': 'TRACTOR',
#    'description': 'The tractor is the front part of the tractor-trailer that pulls the trailer',
#    'weight': '1.0',
#    'rank': '7',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '546'},
#   {'id': '260',
#    'source': 'BERTH',
#    'target': 'BOARD OF COMMISSIONERS',
#    'description': "The Board of Commissioners is responsible for governing the port authority, which in turn manages the berths at a wharf. This governing body has the authority to oversee and manage all berths within the port's jurisdiction, ensuring that the operations at the wharf are conducted efficiently and effectively. The Board's oversight includes the strategic administration of the port's facilities, which encompasses the allocation and maintenance of the berths, a critical component of the port's infrastructure.",
#    'weight': '2.0',
#    'rank': '6',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '260'},
#   {'id': '397',
#    'source': 'FLEETING',
#    'target': 'TUGS',
#    'description': 'Fleeting areas are where tugs are berthed until they are needed',
#    'weight': '1.0',
#    'rank': '5',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '397'},
#   {'id': '568',
#    'source': 'WAY BILL',
#    'target': 'SHIPPER',
#    'description': 'Way bills identify the shipper in the transportation of goods',
#    'weight': '1.0',
#    'rank': '5',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '568'},
#   {'id': '265',
#    'source': 'BOARD OF COMMISSIONERS',
#    'target': 'PORT AUTHORITY',
#    'description': 'The Board of Commissioners is the governing body of a port authority',
#    'weight': '1.0',
#    'rank': '4',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '265'},
#   {'id': '332',
#    'source': 'COMMON CARRIER',
#    'target': 'CONFERENCE RATE',
#    'description': 'Common carriers and conference rates are closely related within the realm of water transportation. Common carriers, which are entities that provide transportation services to the general public under license or authority provided by a regulatory body, may adhere to conference rates. These conference rates are collectively determined by common carriers themselves and are applied to services related to water transportation. This practice allows for standardized pricing within the industry, facilitating a more predictable and transparent cost structure for users of these transportation services.',
#    'weight': '3.0',
#    'rank': '4',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '332'},
#   {'id': '569',
#    'source': 'SHIPPER',
#    'target': 'CONTRACT',
#    'description': 'A contract is an agreement that involves a shipper as one of the parties',
#    'weight': '1.0',
#    'rank': '4',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '569'},
#   {'id': '509',
#    'source': 'RO/RO SHIP',
#    'target': 'VEHICLES',
#    'description': 'Ro/ro ships are specifically designed to transport vehicles that can roll on and off the ship',
#    'weight': '1.0',
#    'rank': '4',
#    'links': '1',
#    'in_context': True,
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '509'}],
#  'claims': [],
#  'sources': [{'id': '59',
#    'text': ' contract between a shipper and carrier listing the terms for moving freight between specified points.\nBoard of Commissioners:\nThe members of the governing board of a port authority are called commissioners. Members of a Board of Commissioners can be elected or appointed and usually serve for several years.\nbollard:\nA line-securing device on a wharf around which mooring and berthing lines are fastened.\nbonded warehouse:\nA building designated by U.S. Customs authorities for storage of goods without payment of duties to Customs until goods are removed.\nBox:\nSlang term for a container.\nbreakbulk cargo:\nNon-containerized general cargo stored in boxes, bales, pallets or other units to be loaded onto or discharged from ships or other forms of transportation. (See also:\nbulk\nand\ncontainer\n.) Examples include iron, steel, machinery, linerboard and woodpulp.\nbulk cargo:\nLoose cargo (dry or liquid) that is loaded (shoveled, scooped, forked, mechanically conveyed or pumped) in volume directly into a ship’s hold; e.g., grain, coal and oil.\nbulkhead\n: A structure used to protect against shifting cargo and/or to separate the load.\nBuoys:\nFloats that warn of hazards such as rocks or shallow ground, to help ships maneuver through unfamiliar harbors.\ncabotage:\nShipment of cargo between a nation’s ports is also called coastwise trade. The U.S. and some other countries require such',
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '290ef1352eee4727f6edc94a10f7676c'},
#   {'id': '56',
#    'text': " to transport cargo. In the maritime industry, cargo is often carried by tractor-trailers. The tractor is the front part of the vehicle, also called a cab. The trailer is the detachable wheeled chassis behind the tractor, on which containers or other cargoes are placed. (See:\ncommon carrier; heavy hauler; drayage\n)\ntugboat:\nStrong v-hull shaped boat used for maneuvering ships into and out of port and to carry supplies. A ship is too powerful to pull up to the wharf on its own. It cuts power and lets the tug nudge it in. Generally barges are pushed by\ntowboats\n, not tugs.\nTwenty Foot Equivalent Unit (TEU):\nA unit of measurement equal to the space occupied by a standard twenty foot container. Used in stating the capacity of container vessel or storage area. One 40 ft. Container is equal to two TEU's.\nU. S. Army Corps of Engineers:\nSee\nCorps of Engineers.\nU. S. Customs:\nSee\nCustoms\n.\nvessel:\nA ship or large boat.\nvessel operator:\nA firm that charters vessels for its service requirements, which are handled by their own offices or appointed agents at ports of call. Vessel operators also handle the operation of vessels on behalf of owners.\nwarehouse:\nA place in which goods or merchandise is stored.\nway bill\n: The document used to identify the shipper and consignee",
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': 'c25139d45688b46490177cf04dab5e03'},
#   {'id': '9',
#    'text': ' concerning the use of an oil tanker for a specific trade.\n  .3 The adequacy of the reception facilities is approved by the Governments of the States Parties to the present Convention.\n  .4 The International Oil Pollution Prevention Certificate is endorsed to the effect that the oil tanker is solely engaged in such specific trade.\n\n#### Regulation 3: Exemptions and waivers\n1. Any ship whose constructional features render the application of any of the provisions of chapters 3 and 4 of this Annex or section 1.2 of part II-A of the Polar Code unreasonable or impracticable may be exempted by the Administration from such provisions.\n2. Particulars of any such exemption shall be indicated in the Certificate referred to in regulation 7 of this Annex.\n3. The Administration which allows any such exemption shall communicate to the Organization particulars of same and the reasons therefore.\n4. The Administration may waive the requirements of regulations 29, 31 and 32 of this Annex, for any oil tanker which engages exclusively on voyages both of 72 hours or less in duration and within 50 nautical miles from the nearest land.\n5. The Administration may waive the requirements of regulations 31 and 32 of this Annex for oil tankers other than those referred to in paragraph 4 of this regulation in cases where:\n.1 The tanker is an oil tanker delivered on or before 1 June 1982, solely engaged in specific trades.\n.2 The tanker is engaged exclusively in',
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '7fef1658b482777f6501772cea0b4647'},
#   {'id': '41',
#    'text': ' They are there to absorb the shock of a ship as it docks at the wharf and to protect the structural pilings that actually support the wharf. Fender piles are also called sacrifice piles since they are designed to be discarded after they are broken.\nfleeting:\nThe area at which barges, towboats and tugs are berthed until needed. The operation of building or dismantling barge tows.\nForeign Trade Zone (FTZ) -\nKnown in some countries as a free zone, a foreign trade zone (FTZ) is a site within the USA (in or near a U.S. Customs port of entry) where foreign and domestic goods are held until they ready to be released into international commerce. If the final product is imported into the U.S., duties and taxes are not due until the goods are release into the U.S. market. Merchandise may enter a FTZ without a formal Customs entry or the payment of Customs duties or government excise taxes. In the zone, goods may be: stored; tested; sampled; repackaged or relabeled; cleaned; combined with other products; repaired or assembled, etc.\nfreight:\nMerchandise hauled by transportation lines.\nfreight forwarder:\nAn individual or company that prepares the documentation and coordinates the movement and storage of export cargoes. See also Customs house broker.\ngantry crane:\nTrack-mounted, shoreside crane utilized in the loading and unloading of breakbulk cargo, containers and heavy',
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '420e22a77fade48d263575fd5929d2de'},
#   {'id': '48',
#    'text': ' repair firms; importers/exporters; pilot associations, etc.\nmarshaling yard:\nThis is a container parking lot, or any open area where containers are stored in a precise order according to the ship loading plan. Containers terminals may use a grounded or wheeled layout. If the cargo box is placed directly on the ground, it is called a grounded operation. If the box is on a chassis/trailer, it is a wheeled operation.\nmean low water (MLW)\n: Lowest average level water reaches on an outgoing tide.\nmean high water (MHW):\nHighest average level water reaches on an outgoing tide.\nmooring dolphin:\nA cluster of pilings to which a boat or barge ties up.\nmotor ship (MS) or motor vessel (MV)\n: A ship propelled by internal-combustion engines.\nNVOCC\n: A non-vessel-owning common carrier that buys space aboard a ship to get a lower volume rate. An NVOCC then sells that space to various small shippers, consolidates their freight, issues bills of lading and books space aboard a ship.\nneo-bulk cargo:\nUniformly packaged goods, such as wood pulp bales, which stow as solidly as bulk, but are handled as general cargoes.\nocean carrier:\nDiesel-fueled vessels have replaced the old steamships of the past, although many people still refer to modern diesel ships as steamships. Likewise, the person who represents the ship in',
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': 'dd7b5aafb754877b5c43bf7c9c30dc96'},
#   {'id': '7',
#    'text': ' no machinery fitted that may use oil or generate oil residue;\n  .4 has no oil fuel tank, lubricating oil tank, oily bilge water holding tank and oil residue tank;\n  .5 has neither persons nor living animals on board.\n\n#### Regulation 2: Application\n1. Unless expressly provided otherwise, the provisions of this Annex shall apply to all ships.\n2. In ships other than oil tankers fitted with cargo spaces which are constructed and utilized to carry oil in bulk of an aggregate capacity of 200 cubic meters or more, the requirements of regulations 16, 26.4, 29, 30, 31, 32, 34 and 36 of this Annex for oil tankers shall also apply to the construction and operation of those spaces.\n3. Where a cargo subject to the provisions of Annex II of the present Convention is carried in a cargo space of an oil tanker, the appropriate requirements of Annex II of the present Convention shall also apply.\n4. The requirements of regulations 29, 31 and 32 of this Annex shall not apply to oil tankers carrying asphalt or other products which through their physical properties inhibit effective product/water separation and monitoring.\n5. Regulations 18.6 to 18.8 of this Annex shall not apply to an oil tanker delivered on or before 1 June 1982, solely engaged in specific trades between ports or terminals within a State Party to the present Convention.\n6. The provisions of paragraph 5',
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': 'b2d6e4b5bacc3d350495c62acb9e58a6'},
#   {'id': '78',
#    'text': " activities for sorting and redistribution of railcars and cargo.\nreefer:\nA container with refrigeration for transporting frozen foods (meat, ice cream, fruit, etc.)\nrefrigeration or reefer units:\nThe protective cooling of perishable freight by ice, liquid nitrogen, or mechanical devices\nro/ro:\nShort for roll on/roll/off . A ro/ro ship is designed with ramps that can be lowered to the dock so cars, buses, trucks or other vehicles can drive into the belly of the ship, rather than be lifted aboard. A ro/ro ship, like a container ship, has a quick turnaround time of about 12 hours.\nRubber-Tired Gantry (RTG):\nTraveling crane used for the movement and positioning of containers in a container field. RTG's may also be used for loading and unloading containers from rail cars.\nsheddage:\nRegardless of the length of stay, a vessel is charged a one-time fee for use of shed space and/or marginal (waterside) rail track space. The charge is based on the length of a vessel.\nshort ton:\nA short ton equals 2,000. Lifting capacity and cargo measurements are designated in short tons.\nSpreader\n: a device for lifting containers by their corner posts. The spreader bar on a container crane is telescopic to allow lifting various length containers.\nsteamship:\nToday, ships that transport cargo overseas are powered by diesel fuel instead of steam. Many people",
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '86a12b6500ae0ff0e8d271159d44a792'},
#   {'id': '73',
#    'text': ' technique involving transfer of commodities to and from the ship using shoreside cranes or ship\'s gear.\nLTL:\nMeans a shipment that is "less than truckload". Cargoes from different sources are usually consolidated to save costs.\nlong ton\n: A long ton equals 2240 pounds.\nlongshoremen:\nDock workers who load and unload ships, or perform administrative tasks associated with the loading or unloading of cargo. They may or may not be members of labor unions. Longshore gangs are hired by stevedoring firms to work the ships. Longshoremen are also called stevedores.\nmanifest:\nThe ship captain’s list of individual goods that make up the ship’s cargo.\nmarine surveyor:\nPerson who inspects a ship hull or its cargo for damage or quality.\nmaster:\nThe officer in charge of the ship. "Captain" is a courtesy title often given to a master.\nmaritime:\n(adjective) Located on or near the sea. Commerce or navigation by sea. The maritime industry includes people working for transportation (ship, rail, truck and towboat/barge) companies, freight forwarders and customs brokers; stevedoring companies; labor unions; chandlers; warehouses; ship building and repair firms; importers/exporters; pilot associations, etc.\nmarshaling yard:\nThis is a container parking lot, or any open area where containers are stored in a precise order according to the ship loading plan. Containers terminals may use a grounded or wheeled layout',
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '294a59a24678a237204168c44226756d'},
#   {'id': '47',
#    'text': 'long ton\n: A long ton equals 2240 pounds.\nlongshoremen:\nDock workers who load and unload ships, or perform administrative tasks associated with the loading or unloading of cargo. They may or may not be members of labor unions. Longshore gangs are hired by stevedoring firms to work the ships. Longshoremen are also called stevedores.\nmanifest:\nThe ship captain’s list of individual goods that make up the ship’s cargo.\nmarine surveyor:\nPerson who inspects a ship hull or its cargo for damage or quality.\nmaster:\nThe officer in charge of the ship. "Captain" is a courtesy title often given to a master.\nmaritime:\n(adjective) Located on or near the sea. Commerce or navigation by sea. The maritime industry includes people working for transportation (ship, rail, truck and towboat/barge) companies, freight forwarders and customs brokers; stevedoring companies; labor unions; chandlers; warehouses; ship building and repair firms; importers/exporters; pilot associations, etc.\nmarshaling yard:\nThis is a container parking lot, or any open area where containers are stored in a precise order according to the ship loading plan. Containers terminals may use a grounded or wheeled layout. If the cargo box is placed directly on the ground, it is called a grounded operation. If the box is on a chassis/trailer, it is a wheeled operation.\nmean low water (MLW)\n: Lowest average level',
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '9b42d50c11e675e8491634850a9c72b5'},
#   {'id': '45',
#    'text': ' and Unloaders of Freight Cars and Barges; Dray Clerks, Weighers and Samplers; plus the Seafarer’s International Union; the National Maritime Union; the Marine Engineers’ Beneficial Association and the Teamsters. Some laborers don’t belong to a union.\nlandlord port:\nAt a landlord port, the port authority builds the wharves, which it then rents or leases to a terminal operator (usually a stevedoring company). The operator invests in cargo-handling equipment (forklifts, cranes, etc), hires longshore laborers to operate such lift machinery and negotiates contracts with ocean carriers (steamship services) to handle the unloading and loading of ship cargoes. (See also\n:\noperating port\n.)\nLASH:\nThese 900-foot-long ships carry small barges inside the vessel. LASH stands for Lighter Aboard Ship. Just as cargo is transported by barge from the shallower parts of the Mississippi River to the Port of New Orleans for export aboard ocean-going ships, LASH barges are lifted into these unusual ships. Overseas, the ship can discharge clusters of barges in the open waters. Then several towboats will assemble the barges into tows bound for various ports and inland waterways, without the ship having to spend time traveling to each port.\nlaunch service:\nCompanies that offer "water-taxi" service to ships at anchor.\nLCL:\nThe acronym for "less',
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '61fdd9ff076a38fb59cc3e1021af4e9e'},
#   {'id': '58',
#    'text': ' has already traveled; a marine transportation carrier’s return movement of cargo, usually opposite from the direction of its primary cargo distribution.\nbarge:\nA large, flat-bottomed boat used to carry cargo from a port to shallow-draft waterways. Barges have no locomotion and are pushed by towboats. A single, standard barge can hold 1,500 tons of cargo or as much as either 15 railroad cars or 60 trucks can carry. A barge is 200 feet long, 35 feet wide and has a draft of 9 feet. Barges carry dry bulk (grain, coal, lumber, gravel, etc.) and liquid bulk (petroleum, vegetable oils, molasses, etc.).\nberth:\n(verb) To bring a ship to a berth. (noun) The wharf space at which a ship docks. A wharf may have two or three berths, depending on the length of incoming ships.\nbill of lading:\nA contract between a shipper and carrier listing the terms for moving freight between specified points.\nBoard of Commissioners:\nThe members of the governing board of a port authority are called commissioners. Members of a Board of Commissioners can be elected or appointed and usually serve for several years.\nbollard:\nA line-securing device on a wharf around which mooring and berthing lines are fastened.\nbonded warehouse:\nA building designated by U.S. Customs authorities for storage of goods without payment of duties',
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '0facc2d00bfe354e735f4bc66311731e'},
#   {'id': '30',
#    'text': 'ways. Barges have no locomotion and are pushed by towboats. A single, standard barge can hold 1,500 tons of cargo or as much as either 15 railroad cars or 60 trucks can carry. A barge is 200 feet long, 35 feet wide and has a draft of 9 feet. Barges carry dry bulk (grain, coal, lumber, gravel, etc.) and liquid bulk (petroleum, vegetable oils, molasses, etc.).\nberth:\n(verb) To bring a ship to a berth. (noun) The wharf space at which a ship docks. A wharf may have two or three berths, depending on the length of incoming ships.\nbill of lading:\nA contract between a shipper and carrier listing the terms for moving freight between specified points.\nBoard of Commissioners:\nThe members of the governing board of a port authority are called commissioners. Members of a Board of Commissioners can be elected or appointed and usually serve for several years.\nbollard:\nA line-securing device on a wharf around which mooring and berthing lines are fastened.\nbonded warehouse:\nA building designated by U.S. Customs authorities for storage of goods without payment of duties to Customs until goods are removed.\nBox:\nSlang term for a container.\nbreakbulk cargo:\nNon-containerized general cargo stored in boxes, bales, pallets or other units to be loaded onto or discharged from ships or other',
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': 'e0135fec749f19b9c3edb8aaa8f6e4b8'},
#   {'id': '31',
#    'text': ' usually serve for several years.\nbollard:\nA line-securing device on a wharf around which mooring and berthing lines are fastened.\nbonded warehouse:\nA building designated by U.S. Customs authorities for storage of goods without payment of duties to Customs until goods are removed.\nBox:\nSlang term for a container.\nbreakbulk cargo:\nNon-containerized general cargo stored in boxes, bales, pallets or other units to be loaded onto or discharged from ships or other forms of transportation. (See also:\nbulk\nand\ncontainer\n.) Examples include iron, steel, machinery, linerboard and woodpulp.\nbulk cargo:\nLoose cargo (dry or liquid) that is loaded (shoveled, scooped, forked, mechanically conveyed or pumped) in volume directly into a ship’s hold; e.g., grain, coal and oil.\nbulkhead\n: A structure used to protect against shifting cargo and/or to separate the load.\nBuoys:\nFloats that warn of hazards such as rocks or shallow ground, to help ships maneuver through unfamiliar harbors.\ncabotage:\nShipment of cargo between a nation’s ports is also called coastwise trade. The U.S. and some other countries require such trade to be carried on domestic ships only.\ncapacity:\nThe available space for, or ability to handle, freight.\ncaptive cargo port:\nWhen most of a port’s inbound cargoes are being shipped short distances and most of its export',
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '473cde568d0f2131c97aca4d1bca1a15'},
#   {'id': '71',
#    'text': ' working conditions. The maritime unions within ports can include locals of the larger union, such as the General Longshore Workers; Clerks and Checkers; Sack-sewers, Sweepers, Water boys and Coopers; Dock Loaders and Unloaders of Freight Cars and Barges; Dray Clerks, Weighers and Samplers; plus the Seafarer’s International Union; the National Maritime Union; the Marine Engineers’ Beneficial Association and the Teamsters. Some laborers don’t belong to a union.\nlandlord port:\nAt a landlord port, the port authority builds the wharves, which it then rents or leases to a terminal operator (usually a stevedoring company). The operator invests in cargo-handling equipment (forklifts, cranes, etc), hires longshore laborers to operate such lift machinery and negotiates contracts with ocean carriers (steamship services) to handle the unloading and loading of ship cargoes. (See also\n:\noperating port\n.)\nLASH:\nThese 900-foot-long ships carry small barges inside the vessel. LASH stands for Lighter Aboard Ship. Just as cargo is transported by barge from the shallower parts of the Mississippi River to the Port of New Orleans for export aboard ocean-going ships, LASH barges are lifted into these unusual ships. Overseas, the ship can discharge clusters of barges in the open waters. Then several towboats will assemble the barges into to',
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '08831bbf674233a2a35c65aff497bcce'},
#   {'id': '77',
#    'text': ' whose occupation is to steep ships along a coast or into and out of a harbor. Local pilots board the ship to advise the captain and navigator of local navigation conditions (difficult currents; hidden wrecks, etc.).\nport:\nThis term is used both for the harbor area where ships are docked and for the agency (port authority), which administers use of public wharves and port properties.\nport-of-call\n: Port at which cruise ship makes a stop along its itinerary. Calls may range from five to 24 hours. Sometimes referred to as "transit port" and "destination port." (See also:\nhome port\n)\nproject cargo:\nThe materials and equipment to assemble a special project overseas, such as a factory or highway.\nquay\n: A wharf, which parallels the waterline.\nrailhead:\nEnd of the railroad line or point in the area of operations at which cargo is loaded and unloaded.\nrailyard:\nA rail terminal at which occur traditional railroad activities for sorting and redistribution of railcars and cargo.\nreefer:\nA container with refrigeration for transporting frozen foods (meat, ice cream, fruit, etc.)\nrefrigeration or reefer units:\nThe protective cooling of perishable freight by ice, liquid nitrogen, or mechanical devices\nro/ro:\nShort for roll on/roll/off . A ro/ro ship is designed with ramps that can be lowered to the dock so cars, buses, trucks or other vehicles can drive into',
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': 'cd60764ffb88b2bd29f71f26056a115c'},
#   {'id': '74',
#    'text': '. The maritime industry includes people working for transportation (ship, rail, truck and towboat/barge) companies, freight forwarders and customs brokers; stevedoring companies; labor unions; chandlers; warehouses; ship building and repair firms; importers/exporters; pilot associations, etc.\nmarshaling yard:\nThis is a container parking lot, or any open area where containers are stored in a precise order according to the ship loading plan. Containers terminals may use a grounded or wheeled layout. If the cargo box is placed directly on the ground, it is called a grounded operation. If the box is on a chassis/trailer, it is a wheeled operation.\nmean low water (MLW)\n: Lowest average level water reaches on an outgoing tide.\nmean high water (MHW):\nHighest average level water reaches on an outgoing tide.\nmooring dolphin:\nA cluster of pilings to which a boat or barge ties up.\nmotor ship (MS) or motor vessel (MV)\n: A ship propelled by internal-combustion engines.\nNVOCC\n: A non-vessel-owning common carrier that buys space aboard a ship to get a lower volume rate. An NVOCC then sells that space to various small shippers, consolidates their freight, issues bills of lading and books space aboard a ship.\nneo-bulk cargo:\nUniformly packaged goods, such as wood pulp bales, which stow as solidly as bulk, but are handled',
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '2e9b153241ef78dd700773d5e47476e3'},
#   {'id': '46',
#    'text': ' Mississippi River to the Port of New Orleans for export aboard ocean-going ships, LASH barges are lifted into these unusual ships. Overseas, the ship can discharge clusters of barges in the open waters. Then several towboats will assemble the barges into tows bound for various ports and inland waterways, without the ship having to spend time traveling to each port.\nlaunch service:\nCompanies that offer "water-taxi" service to ships at anchor.\nLCL:\nThe acronym for "less than container load." It refers to a partial container load that is usually consolidated with other goods to fill a container.\nLength Overall (LOA)\n: Linear measurement of a vessel from bow to stern.\nLift On-Lift Off (LO/LO):\nCargo handling technique involving transfer of commodities to and from the ship using shoreside cranes or ship\'s gear.\nLTL:\nMeans a shipment that is "less than truckload". Cargoes from different sources are usually consolidated to save costs.\nlong ton\n: A long ton equals 2240 pounds.\nlongshoremen:\nDock workers who load and unload ships, or perform administrative tasks associated with the loading or unloading of cargo. They may or may not be members of labor unions. Longshore gangs are hired by stevedoring firms to work the ships. Longshoremen are also called stevedores.\nmanifest:\nThe ship captain’s list of individual goods that make up the ship’s cargo.\nmarine surveyor:\nPerson who ins',
#    'index_name': '2e363fc4952e1bceb38dcaa25e941a61',
#    'index_id': '3aaa274980c4535abe058ce0f18b5270'}]}

# %% [markdown]
# ## Sources
#
# In a query response, citations will often appear that support GraphRAG's response. API endpoints are provided to enable retrieval of the sourced documents, entities, relationships, etc.
#
# Multiple types of sources may be referenced in a query: Reports, Entities, Relationships, Claims, and Text Units. The API provides various endpoints to retrieve these sources for data provenance.

# %% [markdown]
# #### Get a Report

# %%
report_response = get_report(index_name, 0)
print(report_response.json()["text"]) if report_response.ok else (
    report_response.reason,
    report_response.content,
)
# Out:
# # Maritime Administration and Intermodal Transportation Efficiency
#
# The community's structure revolves around the Administration's regulatory role over maritime entities such as SHIP, OIL TANKER, and various certifications like the International Oil Pollution Prevention Certificate. The Administration's authority extends to granting exemptions, issuing certificates, and ensuring compliance with international maritime conventions, which are pivotal for the safe and efficient operation of intermodal transportation.
#
# ## The Administration's Central Regulatory Role
#
# The Administration is the central regulatory authority within the maritime community, holding comprehensive responsibilities for maritime safety, pollution prevention, and compliance with international conventions. It issues critical certificates such as the International Oil Pollution Prevention Certificate and the UNSP Exemption Certificate, which are essential for the legal operation of ships like OIL TANKER and SHIP. The Administration's role is crucial in maintaining the safety and environmental standards of maritime operations, which directly impacts the efficiency of intermodal transportation networks. [records: Entities (82), Relationships (89, 40, 151)]
#
# ## SHIP's Compliance and Operational Efficiency
#
# SHIP, as a large watercraft designed for maritime transportation, is subject to regular surveys and certifications to ensure safety and compliance. The efficient operation of SHIP is vital for intermodal transportation, as it affects the flow of goods and the reliability of supply chains. Compliance with regulations, such as those for oil pollution prevention, directly influences the environmental sustainability and operational efficiency of maritime logistics. [records: Entities (47), Claims (22, 24, 46, 55, 61, 74, 77, 78, 88)]
#
# ## Impact of International Oil Pollution Prevention Certificate
#
# The International Oil Pollution Prevention Certificate (IOPPC) is a document of paramount importance, issued to oil tankers and other ships to certify compliance with MARPOL Annex I regulations. The IOPPC is a testament to a vessel's adherence to international standards aimed at preventing oil pollution, which is a critical aspect of environmental protection in maritime transportation. The certificate's validity, determined by the Administration, underscores the ship's capability to operate within the prescribed environmental norms, thereby influencing the reliability and reputation of intermodal transportation services. [records: Entities (84), Claims (15, 45, 47, 108, 112)]
#
# ## Oil Tanker's Specialized Compliance Requirements
#
# OIL TANKER, designed for the bulk transport of oil, faces specialized compliance requirements due to its cargo. The Administration's ability to grant waivers and exemptions for oil tankers, particularly those engaged in short voyages or specific trades, highlights the flexibility within the regulatory framework to accommodate different operational models. This adaptability is essential for the efficiency of intermodal transportation, as it allows oil tankers to operate under varying conditions while still maintaining safety and environmental standards. [records: Entities (12), Claims (2, 3, 20, 21, 41, 43, 56, 57, 60, 73)]
#
# ## Certificates of Validity and Their Role in Maritime Operations
#
# Certificates of validity, such as the IOPPC and UNSP Exemption Certificate, play a significant role in maritime operations. They serve as proof of a ship's compliance with regulations and are subject to expiration and renewal conditions. The Administration's management of these certificates, including extensions and endorsements, is critical for ensuring that ships can continue their voyages without interruptions, which is essential for the seamless flow of goods in intermodal transportation. [records: Entities (133, 89, 113, 127, 122, 126), Claims (108, 112, 70, 75, 79, 80, 81, 82, 84, 85, 86, 87)]
#
# ## Surveyors and Recognized Organizations as Compliance Enforcers
#
# Surveyors and recognized organizations are authorized by the Administration to conduct surveys and enforce compliance. Their role is to ensure that ships, such as SHIP and OIL TANKER, meet the necessary standards and regulations. This enforcement mechanism is vital for the integrity of maritime operations and, by extension, the efficiency of intermodal transportation. The ability of these entities to mandate repairs and certify compliance supports the overall reliability of the supply chain network. [records: Entities (113, 114), Claims (64, 66, 67, 68, 69)]
#
# ## Port State Control's Influence on Maritime Compliance
#
# Port State Control (PSC) is a critical inspection mechanism that allows port states to examine foreign ships to ensure compliance with international regulations. PSC aims to verify that vessels are equipped, manned, and operated according to international standards, which is essential for the safety and environmental protection of maritime activities. The effectiveness of PSC directly impacts the efficiency of intermodal transportation by ensuring that ships entering and leaving ports meet the required operational conditions. [records: Entities (134), Claims (115, 139)]
#
# ## The Role of U.S. Customs in Maritime Trade Facilitation
#
# U.S. Customs plays a pivotal role in regulating and facilitating international trade, including maritime transportation. It oversees the import and export of goods, ensuring compliance with customs laws and the collection of duties. The efficiency of U.S. Customs operations affects the speed and reliability of intermodal transportation, as it influences the clearance and handling of maritime cargo. Efficient customs processes are essential for minimizing delays and maintaining the flow of goods through supply chains. [records: Entities (199), Claims (250, 246, 138, 141, 249)]
#
# ## Environmental Impact and Compliance with the Polar Code
#
# The Polar Code is a regulatory framework that sets forth safety and environmental standards for ships operating in polar regions. Compliance with the Polar Code is crucial for minimizing the environmental impact of maritime transportation in these sensitive areas. The Code ensures that vessels navigating Arctic and Antarctic waters are properly equipped and operated, which is essential for the sustainability of intermodal transportation networks that extend into polar regions. [records: Entities (90), Claims (91, 175, 184)]

# %% [markdown]
# #### Get an Entity

# %%
entity_response = get_entity(index_name, 0)
entity_response.json() if entity_response.ok else (
    entity_response.reason,
    entity_response.content,
)
# Out:
# {'name': 'INTERNATIONAL MARITIME ORGANIZATION (IMO)',
#  'description': 'The International Maritime Organization is a specialized agency of the United Nations responsible for regulating shipping',
#  'text_units': ['a661a0270a9e2a39ea993d333ed33871']}

# %% [markdown]
# #### Get a Relationship

# %%
relationship_response = get_relationship(index_name, 1)
relationship_response.json() if relationship_response.ok else (
    relationship_response.reason,
    relationship_response.content,
)
# Out:
# {'source': 'MARPOL',
#  'source_id': 1,
#  'target': 'MARPOL ANNEX I',
#  'target_id': 2,
#  'description': 'Annex I is a section of the MARPOL convention focusing on oil pollution prevention',
#  'text_units': ['a661a0270a9e2a39ea993d333ed33871']}

# %% [markdown]
# #### Get a Claim

# %%
claim_response = get_claim(index_name, 1)
if claim_response.ok:
    pprint(claim_response.json())
else:
    print(claim_response)
    print(claim_response.text)
# Out:
# {
#     'covariate_type': 'claim',
#     'type': 'REGULATORY COMPLIANCE',
#     'description': (
#         'The International Maritime Organization (IMO) has complied with the requirements of MSC-MEPC.2/Circ.2 relatin'
#         'g to the carriage of publications on board ships as evidenced by the MARPOL Consolidated Edition 2022 Edition'
#         ', AS AMENDED'
#     ),
#     'subject_id': 'INTERNATIONAL MARITIME ORGANIZATION',
#     'object_id': 'NONE',
#     'source_text': (
#         'This document is a consolidation of official IMO documents, which are available for public use. This consolid'
#         'ation is not sanctioned by the IMO but complies with the requirements of MSC-MEPC.2/Circ.2 relating to the ca'
#         'rriage of publications on board ships.'
#     ),
#     'text_unit_id': 'a661a0270a9e2a39ea993d333ed33871',
#     'document_ids': [
#         'ab39153d70bdb4960d70eb3333622106',
#     ],
# }

# %% [markdown]
# #### Get a Text Unit

# %%
# get a text unit id from one of the previous Source endpoint results (look for 'text_units' in the response)
text_unit_id = ""
if not text_unit_id:
    raise ValueError(
        "Must provide a text_unit_id from previous source results. Look for 'text_units' in the response."
    )
text_unit_response = get_text_unit(index_name, text_unit_id)
if text_unit_response.ok:
    print(text_unit_response.json()["text"])
else:
    print(text_unit_response.reason)
    print(text_unit_response.content)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 4
#       2 text_unit_id = ""
#       3 if not text_unit_id:
# ----> 4     raise ValueError(
#       5         "Must provide a text_unit_id from previous source results. Look for 'text_units' in the response."
#       6     )
#       7 text_unit_response = get_text_unit(index_name, text_unit_id)
#       8 if text_unit_response.ok:
#
# ValueError: Must provide a text_unit_id from previous source results. Look for 'text_units' in the response.

# %% [markdown]
# ## Exploring the GraphRAG knowledge graph
# The API currently provides some basic functionality to better understand the knowledge graph that was constructed during the indexing process.
#
# In addition, an option is available to export the graph to a graphml file which can be imported by other open source visualization software (we recommend [Gephi](https://gephi.org/)) for deeper exploration.

# %% [markdown]
# #### Basic knowledge graph statistics

# %%
response = get_graph_stats(index_name)
print(response)
print(response.text)
# Out:
# <Response [200]>
# {"nodes":431,"edges":584}

# %% [markdown]
# #### Get a GraphML file

# %%
# will save graphml file to the current local directory
save_graphml_file('alfa-laval-mbpx404-index', 'alfa-laval-mbpx404-index'+".graphml")
